# %% [markdown]
# # xQTL Summary
# - Covariates: Age (int) + gender (binary) + years of education (int), 10 principal components (double) = 13 covariates
# - Used ADNI data from website; will focus on ROS/MAP data next

# %%
import pandas as pd
import os
from tqdm.notebook import trange, tqdm
from time import sleep
import matplotlib.pyplot as plt
#from matplotlib_venn import venn3
import numpy as np
import re

# %% [markdown]
# Chucks of code may require a large memory to run and may need an SSH tunnel.
#
# On the remote compute node 'computenode' that is not directly assessible:
# `jupyter notebook --no-browser --port=8889 &`
#
# On the remote machine 'computenode':
# `ssh -NfR 8890:localhost:8889 username@loginnode_name`
#
# On the local machine 'localhost':
# `ssh -NfL 8891:localhost:8890 username@loginnode_full_address`
#
# Now open a web browser on the local machine and type:
# `localhost:8891`

# %% [markdown]
# ## Read summary data

# %% [markdown]
# ### GWAS from Schwartzentruber et al. 2021

# %%
GWAS = pd.read_csv("GWAS_Schwartzentruber_2021/GCST90012877_buildGRCh37.tsv.gz", header=0, index_col=None, delim_whitespace=True)

# %%
GWAS
# Out:
#            variant_id   p_value  chromosome  base_pair_location effect_allele  \
# 0          rs61769339  0.532266           1              662622             A
# 1         rs190214723  0.870407           1              693625             T
# 2          rs12238997  0.834508           1              693731             A
# 3          rs72631875  0.149266           1              705882             A
# 4         rs181440659  0.209173           1              718505             A
# ...               ...       ...         ...                 ...           ...
# 10687072    rs9616985  0.441902          22            51229805             T
# 10687073  rs144549712  0.747566          22            51229855             A
# 10687074    rs9616839  0.492679          22            51233300             T
# 10687075  rs200507571  0.096619          22            51236013             A
# 10687076    rs3896457  0.643251          22            51237063             T
#
#          other_allele  effect_allele_frequency      beta  standard_error  \
# 0                   G                 0.110178  0.012680        0.020303
# 1                   C                 0.950775 -0.006036        0.037000
# 2                   G                 0.884146  0.003903        0.018679
# 3                   G                 0.066959 -0.039365        0.027297
# 4                   G                 0.028718 -0.064142        0.051075
# ...               ...                      ...       ...             ...
# 10687072            C                 0.926815 -0.015827        0.020582
# 10687073            G                 0.143091  0.005819        0.018080
# 10687074            C                 0.334523  0.008820        0.012856
# 10687075           AT                 0.748062 -0.023551        0.014174
# 10687076            C                 0.701278  0.005887        0.012710
#
#                SNP_ID  GWAS_BETA  GWAS_SE   GWAS_P  GWAX_UKBB_BETA  \
# 0          rs61769339    -0.1000   0.0457  0.02869        0.040390
# 1         rs190214723    -0.0163   0.0685  0.81200       -0.001808
# 2          rs12238997     0.0996   0.0413  0.01598       -0.020708
# 3          rs72631875    -0.0184   0.0595  0.75740       -0.044954
# 4         rs181440659    -0.1628   0.1362  0.23200       -0.047998
# ...               ...        ...      ...      ...             ...
# 10687072    rs9616985    -0.0453   0.0385  0.23960       -0.004034
# 10687073  rs144549712    -0.0171   0.0360  0.63490        0.013550
# 10687074    rs9616839     0.0166   0.0235  0.47800        0.005497
# 10687075  rs200507571    -0.0360   0.0293  0.21940       -0.019747
# 10687076    rs3896457     0.0035   0.0244  0.88640        0.006776
#
#           GWAX_UKBB_SE  GWAX_UKBB_P DIRECT        I2     HET_P      INFO
# 0             0.022662        0.089    -++  0.867977  0.005920  0.777266
# 1             0.043966        0.910    --+  0.000000  0.858689  0.438968
# 2             0.020944        0.390    +-+  0.851848  0.009376  0.875969
# 3             0.030720        0.150    --+  0.000000  0.691697  0.672468
# 4             0.055095        0.400    --+  0.000000  0.434576  0.466472
# ...                ...          ...    ...       ...       ...       ...
# 10687072      0.024354        0.880    --+  0.000000  0.365023  0.988928
# 10687073      0.020908        0.530    -++  0.000000  0.461592  0.738075
# 10687074      0.015359        0.810    +++  0.000000  0.692483  0.756590
# 10687075      0.016196        0.160    --+  0.000000  0.627329  0.803616
# 10687076      0.014890        0.610    +++  0.000000  0.908764  0.852165
#
# [10687077 rows x 20 columns]

# %% [markdown]
# The SNP name is `variant_id`. The estimate `beta` is `beta`. The`SE` is `standard_error`.
# Rename the column names to standardize:

# %%
GWAS.rename({'chromosome': 'chr', 'variant_id': 'snps', 'p_value':'pvalue', 'standard_error':'SE', 'base_pair_location':'BP'},
            axis=1,
            inplace=True)
GWAS
# Out:
#                  snps    pvalue  chr        BP effect_allele other_allele  \
# 0          rs61769339  0.532266    1    662622             A            G
# 1         rs190214723  0.870407    1    693625             T            C
# 2          rs12238997  0.834508    1    693731             A            G
# 3          rs72631875  0.149266    1    705882             A            G
# 4         rs181440659  0.209173    1    718505             A            G
# ...               ...       ...  ...       ...           ...          ...
# 10687072    rs9616985  0.441902   22  51229805             T            C
# 10687073  rs144549712  0.747566   22  51229855             A            G
# 10687074    rs9616839  0.492679   22  51233300             T            C
# 10687075  rs200507571  0.096619   22  51236013             A           AT
# 10687076    rs3896457  0.643251   22  51237063             T            C
#
#           effect_allele_frequency      beta        SE       SNP_ID  GWAS_BETA  \
# 0                        0.110178  0.012680  0.020303   rs61769339    -0.1000
# 1                        0.950775 -0.006036  0.037000  rs190214723    -0.0163
# 2                        0.884146  0.003903  0.018679   rs12238997     0.0996
# 3                        0.066959 -0.039365  0.027297   rs72631875    -0.0184
# 4                        0.028718 -0.064142  0.051075  rs181440659    -0.1628
# ...                           ...       ...       ...          ...        ...
# 10687072                 0.926815 -0.015827  0.020582    rs9616985    -0.0453
# 10687073                 0.143091  0.005819  0.018080  rs144549712    -0.0171
# 10687074                 0.334523  0.008820  0.012856    rs9616839     0.0166
# 10687075                 0.748062 -0.023551  0.014174  rs200507571    -0.0360
# 10687076                 0.701278  0.005887  0.012710    rs3896457     0.0035
#
#           GWAS_SE   GWAS_P  GWAX_UKBB_BETA  GWAX_UKBB_SE  GWAX_UKBB_P DIRECT  \
# 0          0.0457  0.02869        0.040390      0.022662        0.089    -++
# 1          0.0685  0.81200       -0.001808      0.043966        0.910    --+
# 2          0.0413  0.01598       -0.020708      0.020944        0.390    +-+
# 3          0.0595  0.75740       -0.044954      0.030720        0.150    --+
# 4          0.1362  0.23200       -0.047998      0.055095        0.400    --+
# ...           ...      ...             ...           ...          ...    ...
# 10687072   0.0385  0.23960       -0.004034      0.024354        0.880    --+
# 10687073   0.0360  0.63490        0.013550      0.020908        0.530    -++
# 10687074   0.0235  0.47800        0.005497      0.015359        0.810    +++
# 10687075   0.0293  0.21940       -0.019747      0.016196        0.160    --+
# 10687076   0.0244  0.88640        0.006776      0.014890        0.610    +++
#
#                 I2     HET_P      INFO
# 0         0.867977  0.005920  0.777266
# 1         0.000000  0.858689  0.438968
# 2         0.851848  0.009376  0.875969
# 3         0.000000  0.691697  0.672468
# 4         0.000000  0.434576  0.466472
# ...            ...       ...       ...
# 10687072  0.000000  0.365023  0.988928
# 10687073  0.000000  0.461592  0.738075
# 10687074  0.000000  0.692483  0.756590
# 10687075  0.000000  0.627329  0.803616
# 10687076  0.000000  0.908764  0.852165
#
# [10687077 rows x 20 columns]

# %% [markdown]
# ### eQTL:
# We use the meta cis-eQTL results from https://adknowledgeportal.synapse.org/Explore/Studies/DetailsPage?Study=syn25398075:
#
# > Here we define "cis" as +/- 1 MB around the gene, and GRCh37 gene locations were used for consistency with the marker imputation panel.
#
# > Cortex_MetaAnalysis : These results have been generated from a combination of the ROSMAP and MayoRNAseq and CommonMind Consortium data.

# %%
eQTL = pd.read_csv("eQTL/Cortex_MetaAnalysis_ROSMAP_CMC_HBCC_Mayo_cis_eQTL_release.csv", header=0, index_col=None, delimiter=',')

# %%
eQTL
# Out:
#            chromosome  snpLocation       snpid         snpLocId  \
# 0                   1       729679   rs4951859     1:729679_C_G
# 1                   1       736289  rs79010578     1:736289_T_A
# 2                   1       752566   rs3094315     1:752566_G_A
# 3                   1       752721   rs3131972     1:752721_A_G
# 4                   1       753405   rs3115860     1:753405_C_A
# ...               ...          ...         ...              ...
# 100080613          22     46541227    rs135557  22:46541227_G_A
# 100080614          22     46543485    rs135556  22:46543485_C_T
# 100080615          22     46544914   rs5767320  22:46544914_T_A
# 100080616          22     46550106   rs4253623  22:46550106_A_G
# 100080617          22     46550315    rs135555  22:46550315_C_G
#
#                       gene geneSymbol  statistic    pvalue       FDR  \
# 0          ENSG00000227232     WASH7P  -0.314474  0.753161  0.962800
# 1          ENSG00000227232     WASH7P   1.189180  0.234369  0.756904
# 2          ENSG00000227232     WASH7P  -0.345971  0.729365  0.958278
# 3          ENSG00000227232     WASH7P  -0.323437  0.746364  0.961634
# 4          ENSG00000227232     WASH7P  -0.699680  0.484127  0.892694
# ...                    ...        ...        ...       ...       ...
# 100080613  ENSG00000273243        NaN   0.708309  0.479130  0.887134
# 100080614  ENSG00000273243        NaN  -0.489167  0.624968  0.933616
# 100080615  ENSG00000273243        NaN  -1.343134  0.179922  0.694412
# 100080616  ENSG00000273243        NaN  -1.343092  0.179936  0.694430
# 100080617  ENSG00000273243        NaN  -0.538175  0.590729  0.924584
#
#                beta A1 A2    A2freq expressionIncreasingAllele  strand  \
# 0         -0.017125  C  G  0.828709                          C    -1.0
# 1          0.074481  T  A  0.141396                          A    -1.0
# 2         -0.017129  G  A  0.825087                          G    -1.0
# 3         -0.015903  A  G  0.823418                          A    -1.0
# 4         -0.037601  C  A  0.847954                          C    -1.0
# ...             ... .. ..       ...                        ...     ...
# 100080613  0.048925  G  A  0.549801                          A     NaN
# 100080614 -0.039056  C  T  0.706972                          C     NaN
# 100080615 -0.136183  T  A  0.138721                          T     NaN
# 100080616 -0.135785  A  G  0.138298                          A     NaN
# 100080617 -0.043136  C  G  0.715835                          C     NaN
#
#                       geneBiotype  geneStartPosition  geneEndPosition
# 0          unprocessed_pseudogene            14404.0          29570.0
# 1          unprocessed_pseudogene            14404.0          29570.0
# 2          unprocessed_pseudogene            14404.0          29570.0
# 3          unprocessed_pseudogene            14404.0          29570.0
# 4          unprocessed_pseudogene            14404.0          29570.0
# ...                           ...                ...              ...
# 100080613                     NaN                NaN              NaN
# 100080614                     NaN                NaN              NaN
# 100080615                     NaN                NaN              NaN
# 100080616                     NaN                NaN              NaN
# 100080617                     NaN                NaN              NaN
#
# [100080618 rows x 18 columns]

# %%
eQTL.set_index(['geneSymbol'], drop=False, inplace=True)

# %% [markdown]
# The SNP name is `snpid`. The estimate `beta` is `beta`. Need to calculate `SE` which is `beta` / `statistic`.

# %% [markdown]
# Then we need to read other xQTLs and use `pd.merge()` to select those xQTLs whose SNP-gene pairs appears in the eQTL file. For this purpose, while `eQTL` is the data frame for SNP-gene pairs, other xQTLs are the data frames for SNP-feature pairs. For example, in the context of pQTL, the feature concerned is protein in UNIPROT symbol.
#
# We also need a table as a dictionary for feature-gene pairs. The dictionary is relatively straightforward in the processed methylQTL file. We need to consult UNIPROT for UNIPROT-gene pairs, and we need some online queries to obtain metabolome-gene pairs.
#
# Due to memory considerations, we first merge the eQTL object (SNP-gene pairs) with the feature-gene pairs, then the result is merged with the xQTL object (SNP-feature pairs).
#
# For methylQTL and metabQTL, we have the additional step of selecting unique SNP-gene pairs based on taking the strongest association.

# %% [markdown]
# ### pQTL
# We use the pQTL results using full ROS/MAP dataset at https://www.synapse.org/#!Synapse:syn24172458.

# %%
pQTL = pd.read_csv("pQTL/ROSMAP_DLPFC_pQTLs.csv", header=0, index_col=None, delimiter=',')

# %%
pQTL
# Out:
#         CHR       POS REF ALT UNIPROT      BETA        SE         P       FDR  \
# 0         1   9500640   G   A  Q9BSK2  0.004091  0.019949  0.837700  0.968298
# 1         1   9501492   G   A  Q9BSK2 -0.014150  0.020643  0.493698  0.852987
# 2         1   9502076   A   G  Q9BSK2 -0.015608  0.018336  0.395487  0.801075
# 3         1   9503008   T   C  Q9BSK2 -0.003667  0.011188  0.743367  0.944384
# 4         1   9505821   T   C  Q9BSK2 -0.015214  0.020834  0.465919  0.839532
# ...     ...       ...  ..  ..     ...       ...       ...       ...       ...
# 786627   22  33498970   T   C  O14994  0.010626  0.010118  0.294456  0.732735
# 786628   22  33500311   G   A  O14994 -0.018149  0.009063  0.046111  0.336052
# 786629   22  33501556   G   A  O14994  0.003150  0.011330  0.781181  0.954182
# 786630   22  33501743   T   C  O14994  0.004832  0.008094  0.550923  0.878009
# 786631   22  33502167   G   A  O14994 -0.015233  0.010057  0.130880  0.545837
#
#           N
# 0       269
# 1       269
# 2       269
# 3       269
# 4       269
# ...     ...
# 786627  330
# 786628  330
# 786629  330
# 786630  330
# 786631  330
#
# [786632 rows x 10 columns]

# %% [markdown]
# Get a list of UNIPROT IDs so that we can query them online for gene IDs:

# %%
pQTL[['UNIPROT']].drop_duplicates().to_csv("pQTL/UNIPROT_IDs.txt", index=False, header=False)

# %% [markdown]
# Submitting a query on https://www.uniprot.org/uploadlists/ from UNIPROT AC/ID to Gene name, we have a dictionary in the file `UNIPROT_IDs_to_gene_names.tab`.

# %%
pQTL_feature_to_genes = pd.read_csv('pQTL/UNIPROT_IDs_to_gene_names.tab', sep='\t')
pQTL_feature_to_genes = pQTL_feature_to_genes.rename({'From': 'UNIPROT', 'To': 'geneSymbol'},
            axis=1)
pQTL_feature_to_genes.set_index('geneSymbol', drop=False, inplace=True)
pQTL_feature_to_genes
# Out:
#            UNIPROT geneSymbol
# geneSymbol
# SLC25A33    Q9BSK2   SLC25A33
# GNB1        P62873       GNB1
# UBE4B       O95155      UBE4B
# ICMT        O60725       ICMT
# DFFA        O00273       DFFA
# ...            ...        ...
# ARSA        P15289       ARSA
# TTLL12      Q14166     TTLL12
# PACSIN2     Q9UNF0    PACSIN2
# TBC1D22A    Q8WUA7   TBC1D22A
# SYN3        O14994       SYN3
#
# [7382 rows x 2 columns]

# %%
pQTL_SNP_to_genes = pQTL_feature_to_genes.join(eQTL,
                                               how = 'inner',
                                               lsuffix = '_x',
                                               rsuffix = '_y')

# %%
pQTL_SNP_to_genes
# Out:
#            UNIPROT geneSymbol_x  chromosome  snpLocation        snpid  \
# geneSymbol
# A1BG        P04217         A1BG          19     57856955   rs10406132
# A1BG        P04217         A1BG          19     57857105    rs1544494
# A1BG        P04217         A1BG          19     57857142   rs73063216
# A1BG        P04217         A1BG          19     57857202   rs73063217
# A1BG        P04217         A1BG          19     57857948    rs2159030
# ...            ...          ...         ...          ...          ...
# ZZEF1       O43149        ZZEF1          17      5044506    rs8065031
# ZZEF1       O43149        ZZEF1          17      5044794    rs2304449
# ZZEF1       O43149        ZZEF1          17      5045034    rs2304448
# ZZEF1       O43149        ZZEF1          17      5045283  rs140256080
# ZZEF1       O43149        ZZEF1          17      5046251   rs12450353
#
#                    snpLocId             gene geneSymbol_y  statistic  \
# geneSymbol
# A1BG        19:57856955_T_C  ENSG00000121410         A1BG   0.566644
# A1BG        19:57857105_C_T  ENSG00000121410         A1BG  -0.716156
# A1BG        19:57857142_C_A  ENSG00000121410         A1BG  -1.603183
# A1BG        19:57857202_T_C  ENSG00000121410         A1BG  -1.463256
# A1BG        19:57857948_T_C  ENSG00000121410         A1BG  -0.610235
# ...                     ...              ...          ...        ...
# ZZEF1        17:5044506_T_A  ENSG00000074755        ZZEF1   0.968502
# ZZEF1        17:5044794_G_A  ENSG00000074755        ZZEF1  -0.745941
# ZZEF1        17:5045034_T_G  ENSG00000074755        ZZEF1  -0.252133
# ZZEF1        17:5045283_T_C  ENSG00000074755        ZZEF1  -0.962268
# ZZEF1        17:5046251_C_T  ENSG00000074755        ZZEF1  -0.300980
#
#               pvalue       FDR      beta A1 A2    A2freq  \
# geneSymbol
# A1BG        0.570956  0.934629  0.031715  T  C  0.325755
# A1BG        0.473895  0.908752 -0.037303  C  T  0.530138
# A1BG        0.108894  0.642906 -0.169437  C  A  0.081109
# A1BG        0.143397  0.698797 -0.153530  T  C  0.081111
# A1BG        0.541706  0.927423 -0.037554  T  C  0.764907
# ...              ...       ...       ... .. ..       ...
# ZZEF1       0.332794  0.813380  0.059109  T  A  0.101610
# ZZEF1       0.455703  0.872488 -0.055736  G  A  0.070402
# ZZEF1       0.800938  0.968441 -0.012295  T  G  0.821175
# ZZEF1       0.335915  0.815243 -0.052422  T  C  0.138028
# ZZEF1       0.763430  0.961017 -0.011625  C  T  0.647785
#
#            expressionIncreasingAllele  strand     geneBiotype  \
# geneSymbol
# A1BG                                C    -1.0  protein_coding
# A1BG                                C    -1.0  protein_coding
# A1BG                                C    -1.0  protein_coding
# A1BG                                T    -1.0  protein_coding
# A1BG                                T    -1.0  protein_coding
# ...                               ...     ...             ...
# ZZEF1                               A    -1.0  protein_coding
# ZZEF1                               G    -1.0  protein_coding
# ZZEF1                               T    -1.0  protein_coding
# ZZEF1                               T    -1.0  protein_coding
# ZZEF1                               C    -1.0  protein_coding
#
#             geneStartPosition  geneEndPosition
# geneSymbol
# A1BG               58345178.0       58353499.0
# A1BG               58345178.0       58353499.0
# A1BG               58345178.0       58353499.0
# A1BG               58345178.0       58353499.0
# A1BG               58345178.0       58353499.0
# ...                       ...              ...
# ZZEF1               4004445.0        4143020.0
# ZZEF1               4004445.0        4143020.0
# ZZEF1               4004445.0        4143020.0
# ZZEF1               4004445.0        4143020.0
# ZZEF1               4004445.0        4143020.0
#
# [35050071 rows x 20 columns]

# %%
pQTL.set_index(['UNIPROT', 'POS', 'CHR'], drop=False, inplace=True)

# %%
pQTL_SNP_to_genes.set_index(['UNIPROT', 'snpLocation', 'chromosome'], drop=False, inplace=True)

# %%
pQTL_SNP_to_genes.index.names = ['UNIPROT', 'POS', 'CHR']

# %%
pQTL_overlapping_eQTL = pQTL.join(pQTL_SNP_to_genes, 
           how='inner', lsuffix='_x', rsuffix='_y')

# %%
pQTL_overlapping_eQTL
# Out:
#                        CHR        POS REF ALT UNIPROT_x      BETA        SE  \
# UNIPROT POS       CHR
# A0AVF1  138719231 7      7  138719231   T   C    A0AVF1  0.028552  0.020807
#         138721021 7      7  138721021   A   G    A0AVF1  0.028289  0.021064
#         138721868 7      7  138721868   G   A    A0AVF1  0.027424  0.020904
#         138726383 7      7  138726383   T   G    A0AVF1  0.028895  0.021247
#         138729795 7      7  138729795   A   C    A0AVF1  0.026994  0.020313
# ...                    ...        ...  ..  ..       ...       ...       ...
# Q9Y6Y8  121796742 10    10  121796742   G   T    Q9Y6Y8 -0.012629  0.005751
#         121797067 10    10  121797067   T   G    Q9Y6Y8 -0.012899  0.006588
#         121798022 10    10  121798022   C   T    Q9Y6Y8  0.004897  0.007518
#         121798207 10    10  121798207   C   T    Q9Y6Y8  0.018308  0.009082
#         121803633 10    10  121803633   C   T    Q9Y6Y8 -0.012801  0.005738
#
#                               P     FDR_x    N  ...     FDR_y      beta  A1  \
# UNIPROT POS       CHR                           ...
# A0AVF1  138719231 7    0.172066  0.607685  172  ...  0.830474  0.032313   T
#         138721021 7    0.181335  0.619615  172  ...  0.691650  0.047682   A
#         138721868 7    0.191580  0.631962  172  ...  0.614366  0.054792   G
#         138726383 7    0.175911  0.613071  172  ...  0.716628  0.045350   T
#         138729795 7    0.185932  0.625461  172  ...  0.864338  0.027546   A
# ...                         ...       ...  ...  ...       ...       ...  ..
# Q9Y6Y8  121796742 10   0.028850  0.261079  330  ...  0.731878 -0.044667   G
#         121797067 10   0.051145  0.354094  330  ...  0.814466 -0.038205   T
#         121798022 10   0.515319  0.862697  330  ...  0.980941  0.007257   C
#         121798207 10   0.044695  0.330450  330  ...  0.803624  0.057929   C
#         121803633 10   0.026417  0.248366  330  ...  0.732937 -0.044689   C
#
#                        A2    A2freq expressionIncreasingAllele strand  \
# UNIPROT POS       CHR
# A0AVF1  138719231 7     C  0.536944                          C    1.0
#         138721021 7     G  0.509803                          G    1.0
#         138721868 7     A  0.506361                          A    1.0
#         138726383 7     G  0.514272                          G    1.0
#         138729795 7     C  0.520558                          C    1.0
# ...                    ..       ...                        ...    ...
# Q9Y6Y8  121796742 10    T  0.521635                          G    1.0
#         121797067 10    G  0.709971                          T    1.0
#         121798022 10    T  0.199385                          T    1.0
#         121798207 10    T  0.108331                          T    1.0
#         121803633 10    T  0.519077                          C    1.0
#
#                           geneBiotype  geneStartPosition  geneEndPosition
# UNIPROT POS       CHR
# A0AVF1  138719231 7    protein_coding        139133744.0      139191986.0
#         138721021 7    protein_coding        139133744.0      139191986.0
#         138721868 7    protein_coding        139133744.0      139191986.0
#         138726383 7    protein_coding        139133744.0      139191986.0
#         138729795 7    protein_coding        139133744.0      139191986.0
# ...                               ...                ...              ...
# Q9Y6Y8  121796742 10   protein_coding        119892711.0      119944658.0
#         121797067 10   protein_coding        119892711.0      119944658.0
#         121798022 10   protein_coding        119892711.0      119944658.0
#         121798207 10   protein_coding        119892711.0      119944658.0
#         121803633 10   protein_coding        119892711.0      119944658.0
#
# [731435 rows x 30 columns]

# %%
pQTL_overlapping_eQTL_idxmin = pQTL_overlapping_eQTL.reset_index(drop=True)

# %%
pQTL_overlapping_eQTL_idxmin = pQTL_overlapping_eQTL_idxmin.loc[
    pQTL_overlapping_eQTL_idxmin.groupby(['CHR','POS','geneSymbol_x']).P.idxmin()].reset_index(drop=True)

# %%
pQTL_overlapping_eQTL_idxmin
# Out:
#         CHR       POS REF ALT UNIPROT_x      BETA        SE         P  \
# 0         1    785989   T   C    Q9Y3T9  0.029488  0.013028  0.024436
# 1         1    838555   C   A    Q9Y3T9 -0.000840  0.010713  0.937601
# 2         1    846808   C   T    Q9Y3T9 -0.000272  0.012387  0.982476
# 3         1    853954   C   A    P05161 -0.030620  0.028156  0.277683
# 4         1    853954   C   A    Q9Y3T9  0.013592  0.009404  0.149576
# ...     ...       ...  ..  ..       ...       ...       ...       ...
# 730518   22  51175626   A   G    Q9BYB0 -0.010342  0.010616  0.330724
# 730519   22  51178090   G   A    Q9UNT1 -0.000572  0.054131  0.991581
# 730520   22  51178090   G   A    Q9BYB0 -0.009642  0.011195  0.389769
# 730521   22  51186228   C   T    Q9UNT1  0.041947  0.026233  0.111460
# 730522   22  51186228   C   T    Q9BYB0 -0.009241  0.005344  0.084795
#
#            FDR_x    N  ...         FDR_y      beta  A1  A2    A2freq  \
# 0       0.236994  282  ...  8.132205e-01 -0.055421   T   C  0.836686
# 1       0.989479  282  ...  9.544147e-01 -0.020273   C   A  0.267010
# 2       0.997482  282  ...  7.174384e-01  0.076048   C   T  0.204360
# 3       0.719025  323  ...  1.022552e-01  0.144398   C   A  0.578350
# 4       0.575695  282  ...  2.506713e-01 -0.122236   C   A  0.578350
# ...          ...  ...  ...           ...       ...  ..  ..       ...
# 730518  0.759008  330  ...  9.901694e-01  0.007379   A   G  0.068315
# 730519  0.998953  216  ...  3.150560e-25  0.863730   G   A  0.060391
# 730520  0.797619  330  ...  9.735880e-01  0.019784   G   A  0.060391
# 730521  0.509686  216  ...  1.805755e-01  0.097829   C   T  0.450743
# 730522  0.451143  330  ...  6.120883e-01 -0.060464   C   T  0.450743
#
#        expressionIncreasingAllele strand     geneBiotype  geneStartPosition  \
# 0                               T   -1.0  protein_coding           944204.0
# 1                               C   -1.0  protein_coding           944204.0
# 2                               T   -1.0  protein_coding           944204.0
# 3                               A    1.0  protein_coding          1001138.0
# 4                               C   -1.0  protein_coding           944204.0
# ...                           ...    ...             ...                ...
# 730518                          G    1.0  protein_coding         50674415.0
# 730519                          A   -1.0  protein_coding         50767501.0
# 730520                          A    1.0  protein_coding         50674415.0
# 730521                          T   -1.0  protein_coding         50767501.0
# 730522                          C    1.0  protein_coding         50674415.0
#
#         geneEndPosition
# 0              959309.0
# 1              959309.0
# 2              959309.0
# 3             1014541.0
# 4              959309.0
# ...                 ...
# 730518       50733298.0
# 730519       50783663.0
# 730520       50733298.0
# 730521       50783663.0
# 730522       50733298.0
#
# [730523 rows x 30 columns]

# %%
os.makedirs('analysis_using_meta_eQTL', exist_ok = True)
pQTL_overlapping_eQTL_idxmin.to_csv("analysis_using_meta_eQTL/pQTL_overlapping_eQTL.csv", index=False)

# %%
pQTL_overlapping_eQTL_idxmin.columns
# Out:
# Index(['CHR', 'POS', 'REF', 'ALT', 'UNIPROT_x', 'BETA', 'SE', 'P', 'FDR_x',
#        'N', 'UNIPROT_y', 'geneSymbol_x', 'chromosome', 'snpLocation', 'snpid',
#        'snpLocId', 'gene', 'geneSymbol_y', 'statistic', 'pvalue', 'FDR_y',
#        'beta', 'A1', 'A2', 'A2freq', 'expressionIncreasingAllele', 'strand',
#        'geneBiotype', 'geneStartPosition', 'geneEndPosition'],
#       dtype='object')

# %% [markdown]
# The SNP name is `snpid`. The estimate `beta` is `BETA`. The standard error estimator `SE` is `SE`.

# %% [markdown]
# ### metabQTL
# - files:
# - (fia) metabQTL/fia-metabQTL-1_long.zip
# - (uplc) metabQTL/uplc-metabQTL-1.zip

# %% [markdown]
# #### Obtain the mapping from features (metabolites) to genes

# %%
# we only extract the mapping from features (metabolites) to genes 
# instead of using the actual summary statistics in the file:
metabQTL_uplc = pd.read_csv("metabQTL/uplc-metabQTL-1e-4-UPDATED.csv", header=0, index_col=None, delimiter=",")

# %%
metabQTL_uplc.rename({'gene':'ADNI_ID'}, axis=1, inplace=True)
metabQTL_uplc
# Out:
#              snps    ADNI_ID  statistic        pvalue       FDR       beta  \
# 0       rs2069707   P180_M15   6.252548  3.405343e-09  0.097573  29.853509
# 1      rs34899222   P180_M15   5.829532  2.898698e-08  0.238744  30.443130
# 2      rs79155407   P180_M15   5.493135  1.491041e-07  0.404814  28.285716
# 3       rs2728114   P180_M15   5.301367  3.689894e-07  0.452393  15.111635
# 4       rs1994909   P180_M15   5.292062  3.853734e-07  0.452393  18.217046
# ...           ...        ...        ...           ...       ...        ...
# 16921  rs11930225  P180_M195  -3.997078  9.695950e-05  0.902450  -7.473984
# 16922   rs6973276  P180_M195   3.996257  9.726601e-05  0.902450   4.750904
# 16923   rs6439260  P180_M195   3.995839  9.742215e-05  0.902450   5.485977
# 16924   rs9509821  P180_M195   3.991573  9.903196e-05  0.906106   4.870799
# 16925  rs57931062  P180_M195   3.990274  9.952727e-05  0.906630   9.953828
#
#              Name    KEGG                                              genes
# 0      Creatinine  C00791  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 1      Creatinine  C00791  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 2      Creatinine  C00791  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 3      Creatinine  C00791  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 4      Creatinine  C00791  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# ...           ...     ...                                                ...
# 16921         Trp  C00078  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16922         Trp  C00078  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16923         Trp  C00078  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16924         Trp  C00078  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16925         Trp  C00078  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
#
# [16926 rows x 9 columns]

# %%
# extract name and genes and then do a merge (join)
compound_to_gene_uplc = metabQTL_uplc.loc[:, ['ADNI_ID','genes']].drop_duplicates()
compound_to_gene_uplc
# Out:
#          ADNI_ID                                              genes
# 0       P180_M15  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 940    P180_M193  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 1872   P180_M166  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 2652     P180_M6  ['HIF1A', 'MAT1A', 'AADAT', 'PIK3CA', 'NSD1', ...
# 3164    P180_M29  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 4140   P180_M187  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 4403    P180_M27  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'NPR2', ...
# 5142     P180_M5  ['HIF1A', 'MAT1A', 'AADAT', 'PIK3CA', 'NSD1', ...
# 5860   P180_M159  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 6517    P180_M81  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 6957    P180_M26  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 7451   P180_M196  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 8142   P180_M191  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 8948    P180_M37  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 9508   P180_M162  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 10041  P180_M168  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 10468  P180_M184  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 11109  P180_M197  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 11740    P180_M4  ['MAT1A', 'AADAT', 'NSD1', 'ADSS1', 'DOT1L', '...
# 12277    P180_M3  ['MAT1A', 'ADSS1', 'ADO', 'AGXT2', 'BHMT', 'AB...
# 12713  P180_M167  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 13291    P180_M7  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 13813   P180_M14  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 14379   P180_M70  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 14848   P180_M53  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 15331   P180_M49  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 15833   P180_M51  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16443  P180_M195  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...

# %%
# extract name and genes and then do a merge (join)
compound_to_gene_fia = pd.read_csv("metabQTL/fiaa_metabs_mapping.csv", header=0, index_col=None, delimiter=",")
compound_to_gene_fia
# Out:
#                 Compound   ADNI_ID KEGG_ID  \
# 0         lysoPC.a.C17.0  P180_M57  C04317
# 1         lysoPC.a.C18.1  P180_M59  C04230
# 2         lysoPC.a.C20.3  P180_M61  C04230
# 3         lysoPC.a.C20.4  P180_M62  C04230
# 4  Hexadecanoylcarnitine  P180_M31  C02990
#
#                                                genes
# 0  ['PAFAH2', 'PLA2G4E', 'PLA2G2E', 'CHPT1', 'PLP...
# 1  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 2  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 3  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 4  ['ALDH9A1', 'ADH7', 'ACSL3', 'CYP4A22', 'ACSL6...

# %%
compound_to_gene_fia = compound_to_gene_fia.loc[:,['ADNI_ID','genes']]
compound_to_gene_fia
# Out:
#     ADNI_ID                                              genes
# 0  P180_M57  ['PAFAH2', 'PLA2G4E', 'PLA2G2E', 'CHPT1', 'PLP...
# 1  P180_M59  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 2  P180_M61  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 3  P180_M62  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 4  P180_M31  ['ALDH9A1', 'ADH7', 'ACSL3', 'CYP4A22', 'ACSL6...

# %%
compound_to_gene = pd.concat([compound_to_gene_uplc,compound_to_gene_fia], ignore_index = True)
compound_to_gene
# Out:
#       ADNI_ID                                              genes
# 0    P180_M15  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 1   P180_M193  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 2   P180_M166  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 3     P180_M6  ['HIF1A', 'MAT1A', 'AADAT', 'PIK3CA', 'NSD1', ...
# 4    P180_M29  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 5   P180_M187  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 6    P180_M27  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'NPR2', ...
# 7     P180_M5  ['HIF1A', 'MAT1A', 'AADAT', 'PIK3CA', 'NSD1', ...
# 8   P180_M159  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 9    P180_M81  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 10   P180_M26  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 11  P180_M196  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 12  P180_M191  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 13   P180_M37  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 14  P180_M162  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 15  P180_M168  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 16  P180_M184  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 17  P180_M197  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 18    P180_M4  ['MAT1A', 'AADAT', 'NSD1', 'ADSS1', 'DOT1L', '...
# 19    P180_M3  ['MAT1A', 'ADSS1', 'ADO', 'AGXT2', 'BHMT', 'AB...
# 20  P180_M167  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 21    P180_M7  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 22   P180_M14  ['ALDH3B2', 'NAMPT', 'NSD1', 'DOT1L', 'ABCC4',...
# 23   P180_M70  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 24   P180_M53  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 25   P180_M49  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 26   P180_M51  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 27  P180_M195  ['CP', 'ALDH3B2', 'NAMPT', 'NSD1', 'IDH2', 'CO...
# 28   P180_M57  ['PAFAH2', 'PLA2G4E', 'PLA2G2E', 'CHPT1', 'PLP...
# 29   P180_M59  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 30   P180_M61  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 31   P180_M62  ['LPGAT1', 'ADPRM', 'PLA2G2E', 'PLPP2', 'CHPT1...
# 32   P180_M31  ['ALDH9A1', 'ADH7', 'ACSL3', 'CYP4A22', 'ACSL6...

# %%
compound_to_gene_list = [pd.DataFrame([[x, w] for w in re.split("^\['|', '|'\]$", y)[1:-1]], columns = ['ADNI_ID', 'gene']) \
                      for x, y in zip(compound_to_gene['ADNI_ID'], compound_to_gene['genes'])]
compound_to_gene_list
# Out:
# [      ADNI_ID     gene
#  0    P180_M15  ALDH3B2
#  1    P180_M15    NAMPT
#  2    P180_M15     NSD1
#  3    P180_M15    DOT1L
#  4    P180_M15    ABCC4
#  ..        ...      ...
#  316  P180_M15    PANK3
#  317  P180_M15     GNMT
#  318  P180_M15     MAOA
#  319  P180_M15     ULK3
#  320  P180_M15    ABCG5
#
#  [321 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M193       CP
#  1    P180_M193  ALDH3B2
#  2    P180_M193    NAMPT
#  3    P180_M193     NSD1
#  4    P180_M193     IDH2
#  ..         ...      ...
#  930  P180_M193   POLR2I
#  931  P180_M193      AK4
#  932  P180_M193   AKR1D1
#  933  P180_M193    HADHB
#  934  P180_M193    ABCG5
#
#  [935 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M166       CP
#  1    P180_M166  ALDH3B2
#  2    P180_M166    NAMPT
#  3    P180_M166     NSD1
#  4    P180_M166     IDH2
#  ..         ...      ...
#  807  P180_M166   POLR2I
#  808  P180_M166      AK4
#  809  P180_M166   AKR1D1
#  810  P180_M166    HADHB
#  811  P180_M166    ABCG5
#
#  [812 rows x 2 columns],
#       ADNI_ID     gene
#  0    P180_M6    HIF1A
#  1    P180_M6    MAT1A
#  2    P180_M6    AADAT
#  3    P180_M6   PIK3CA
#  4    P180_M6     NSD1
#  ..       ...      ...
#  240  P180_M6     MAOA
#  241  P180_M6     ULK3
#  242  P180_M6  ALDH1B1
#  243  P180_M6   DNMT3B
#  244  P180_M6    ABCG5
#
#  [245 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M29       CP
#  1    P180_M29  ALDH3B2
#  2    P180_M29    NAMPT
#  3    P180_M29     NSD1
#  4    P180_M29     IDH2
#  ..        ...      ...
#  757  P180_M29    FXYD2
#  758  P180_M29   POLR2I
#  759  P180_M29      AK4
#  760  P180_M29   AKR1D1
#  761  P180_M29    ABCG5
#
#  [762 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M187       CP
#  1    P180_M187  ALDH3B2
#  2    P180_M187    NAMPT
#  3    P180_M187     NSD1
#  4    P180_M187     IDH2
#  ..         ...      ...
#  930  P180_M187   POLR2I
#  931  P180_M187      AK4
#  932  P180_M187   AKR1D1
#  933  P180_M187    HADHB
#  934  P180_M187    ABCG5
#
#  [935 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M27  ALDH3B2
#  1    P180_M27    NAMPT
#  2    P180_M27     NSD1
#  3    P180_M27    DOT1L
#  4    P180_M27     NPR2
#  ..        ...      ...
#  528  P180_M27    PDE4D
#  529  P180_M27    FXYD2
#  530  P180_M27   POLR2I
#  531  P180_M27      AK4
#  532  P180_M27    ABCG5
#
#  [533 rows x 2 columns],
#       ADNI_ID     gene
#  0    P180_M5    HIF1A
#  1    P180_M5    MAT1A
#  2    P180_M5    AADAT
#  3    P180_M5   PIK3CA
#  4    P180_M5     NSD1
#  ..       ...      ...
#  240  P180_M5     MAOA
#  241  P180_M5     ULK3
#  242  P180_M5  ALDH1B1
#  243  P180_M5   DNMT3B
#  244  P180_M5    ABCG5
#
#  [245 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M159       CP
#  1    P180_M159  ALDH3B2
#  2    P180_M159    NAMPT
#  3    P180_M159     NSD1
#  4    P180_M159     IDH2
#  ..         ...      ...
#  807  P180_M159   POLR2I
#  808  P180_M159      AK4
#  809  P180_M159   AKR1D1
#  810  P180_M159    HADHB
#  811  P180_M159    ABCG5
#
#  [812 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M81       CP
#  1    P180_M81  ALDH3B2
#  2    P180_M81    NAMPT
#  3    P180_M81     NSD1
#  4    P180_M81     IDH2
#  ..        ...      ...
#  802  P180_M81   POLR2I
#  803  P180_M81      AK4
#  804  P180_M81   AKR1D1
#  805  P180_M81    HADHB
#  806  P180_M81    ABCG5
#
#  [807 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M26       CP
#  1    P180_M26  ALDH3B2
#  2    P180_M26    NAMPT
#  3    P180_M26     NSD1
#  4    P180_M26     IDH2
#  ..        ...      ...
#  742  P180_M26    PDE4D
#  743  P180_M26    FXYD2
#  744  P180_M26   POLR2I
#  745  P180_M26      AK4
#  746  P180_M26    ABCG5
#
#  [747 rows x 2 columns],
#          ADNI_ID     gene
#  0     P180_M196       CP
#  1     P180_M196  ALDH3B2
#  2     P180_M196    NAMPT
#  3     P180_M196     NSD1
#  4     P180_M196     IDH2
#  ...         ...      ...
#  1012  P180_M196   POLR2I
#  1013  P180_M196      AK4
#  1014  P180_M196   AKR1D1
#  1015  P180_M196    HADHB
#  1016  P180_M196    ABCG5
#
#  [1017 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M191       CP
#  1    P180_M191  ALDH3B2
#  2    P180_M191    NAMPT
#  3    P180_M191     NSD1
#  4    P180_M191     IDH2
#  ..         ...      ...
#  930  P180_M191   POLR2I
#  931  P180_M191      AK4
#  932  P180_M191   AKR1D1
#  933  P180_M191    HADHB
#  934  P180_M191    ABCG5
#
#  [935 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M37       CP
#  1    P180_M37  ALDH3B2
#  2    P180_M37    NAMPT
#  3    P180_M37     NSD1
#  4    P180_M37     IDH2
#  ..        ...      ...
#  757  P180_M37    FXYD2
#  758  P180_M37   POLR2I
#  759  P180_M37      AK4
#  760  P180_M37   AKR1D1
#  761  P180_M37    ABCG5
#
#  [762 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M162       CP
#  1    P180_M162  ALDH3B2
#  2    P180_M162    NAMPT
#  3    P180_M162     NSD1
#  4    P180_M162     IDH2
#  ..         ...      ...
#  807  P180_M162   POLR2I
#  808  P180_M162      AK4
#  809  P180_M162   AKR1D1
#  810  P180_M162    HADHB
#  811  P180_M162    ABCG5
#
#  [812 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M168       CP
#  1    P180_M168  ALDH3B2
#  2    P180_M168    NAMPT
#  3    P180_M168     NSD1
#  4    P180_M168     IDH2
#  ..         ...      ...
#  930  P180_M168   POLR2I
#  931  P180_M168      AK4
#  932  P180_M168   AKR1D1
#  933  P180_M168    HADHB
#  934  P180_M168    ABCG5
#
#  [935 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M184       CP
#  1    P180_M184  ALDH3B2
#  2    P180_M184    NAMPT
#  3    P180_M184     NSD1
#  4    P180_M184     IDH2
#  ..         ...      ...
#  930  P180_M184   POLR2I
#  931  P180_M184      AK4
#  932  P180_M184   AKR1D1
#  933  P180_M184    HADHB
#  934  P180_M184    ABCG5
#
#  [935 rows x 2 columns],
#          ADNI_ID     gene
#  0     P180_M197       CP
#  1     P180_M197  ALDH3B2
#  2     P180_M197    NAMPT
#  3     P180_M197     NSD1
#  4     P180_M197     IDH2
#  ...         ...      ...
#  1012  P180_M197   POLR2I
#  1013  P180_M197      AK4
#  1014  P180_M197   AKR1D1
#  1015  P180_M197    HADHB
#  1016  P180_M197    ABCG5
#
#  [1017 rows x 2 columns],
#       ADNI_ID     gene
#  0    P180_M4    MAT1A
#  1    P180_M4    AADAT
#  2    P180_M4     NSD1
#  3    P180_M4    ADSS1
#  4    P180_M4    DOT1L
#  ..       ...      ...
#  153  P180_M4   ABCB11
#  154  P180_M4   ABCA12
#  155  P180_M4  ALDH1B1
#  156  P180_M4   DNMT3B
#  157  P180_M4    ABCG5
#
#  [158 rows x 2 columns],
#       ADNI_ID    gene
#  0    P180_M3   MAT1A
#  1    P180_M3   ADSS1
#  2    P180_M3     ADO
#  3    P180_M3   AGXT2
#  4    P180_M3    BHMT
#  ..       ...     ...
#  109  P180_M3    CFTR
#  110  P180_M3  ABCB11
#  111  P180_M3  ABCA12
#  112  P180_M3  DNMT3B
#  113  P180_M3   ABCG5
#
#  [114 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M167       CP
#  1    P180_M167  ALDH3B2
#  2    P180_M167    NAMPT
#  3    P180_M167     NSD1
#  4    P180_M167     IDH2
#  ..         ...      ...
#  930  P180_M167   POLR2I
#  931  P180_M167      AK4
#  932  P180_M167   AKR1D1
#  933  P180_M167    HADHB
#  934  P180_M167    ABCG5
#
#  [935 rows x 2 columns],
#       ADNI_ID     gene
#  0    P180_M7  ALDH3B2
#  1    P180_M7    NAMPT
#  2    P180_M7     NSD1
#  3    P180_M7    DOT1L
#  4    P180_M7    ABCC4
#  ..       ...      ...
#  316  P180_M7    PANK3
#  317  P180_M7     GNMT
#  318  P180_M7     MAOA
#  319  P180_M7     ULK3
#  320  P180_M7    ABCG5
#
#  [321 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M14  ALDH3B2
#  1    P180_M14    NAMPT
#  2    P180_M14     NSD1
#  3    P180_M14    DOT1L
#  4    P180_M14    ABCC4
#  ..        ...      ...
#  316  P180_M14    PANK3
#  317  P180_M14     GNMT
#  318  P180_M14     MAOA
#  319  P180_M14     ULK3
#  320  P180_M14    ABCG5
#
#  [321 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M70       CP
#  1    P180_M70  ALDH3B2
#  2    P180_M70    NAMPT
#  3    P180_M70     NSD1
#  4    P180_M70     IDH2
#  ..        ...      ...
#  802  P180_M70   POLR2I
#  803  P180_M70      AK4
#  804  P180_M70   AKR1D1
#  805  P180_M70    HADHB
#  806  P180_M70    ABCG5
#
#  [807 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M53       CP
#  1    P180_M53  ALDH3B2
#  2    P180_M53    NAMPT
#  3    P180_M53     NSD1
#  4    P180_M53     IDH2
#  ..        ...      ...
#  802  P180_M53   POLR2I
#  803  P180_M53      AK4
#  804  P180_M53   AKR1D1
#  805  P180_M53    HADHB
#  806  P180_M53    ABCG5
#
#  [807 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M49       CP
#  1    P180_M49  ALDH3B2
#  2    P180_M49    NAMPT
#  3    P180_M49     NSD1
#  4    P180_M49     IDH2
#  ..        ...      ...
#  784  P180_M49   POLR2I
#  785  P180_M49      AK4
#  786  P180_M49   AKR1D1
#  787  P180_M49    HADHB
#  788  P180_M49    ABCG5
#
#  [789 rows x 2 columns],
#        ADNI_ID     gene
#  0    P180_M51       CP
#  1    P180_M51  ALDH3B2
#  2    P180_M51    NAMPT
#  3    P180_M51     NSD1
#  4    P180_M51     IDH2
#  ..        ...      ...
#  802  P180_M51   POLR2I
#  803  P180_M51      AK4
#  804  P180_M51   AKR1D1
#  805  P180_M51    HADHB
#  806  P180_M51    ABCG5
#
#  [807 rows x 2 columns],
#         ADNI_ID     gene
#  0    P180_M195       CP
#  1    P180_M195  ALDH3B2
#  2    P180_M195    NAMPT
#  3    P180_M195     NSD1
#  4    P180_M195     IDH2
#  ..         ...      ...
#  930  P180_M195   POLR2I
#  931  P180_M195      AK4
#  932  P180_M195   AKR1D1
#  933  P180_M195    HADHB
#  934  P180_M195    ABCG5
#
#  [935 rows x 2 columns],
#       ADNI_ID           gene
#  0   P180_M57         PAFAH2
#  1   P180_M57        PLA2G4E
#  2   P180_M57        PLA2G2E
#  3   P180_M57          CHPT1
#  4   P180_M57          PLPP2
#  5   P180_M57        PLA2G1B
#  6   P180_M57         PLA2G5
#  7   P180_M57           PLD1
#  8   P180_M57        PLA2G2D
#  9   P180_M57        PLA2G2C
#  10  P180_M57         PLA2G7
#  11  P180_M57       PAFAH1B2
#  12  P180_M57        PLA2G4A
#  13  P180_M57       PAFAH1B1
#  14  P180_M57         PLA2G3
#  15  P180_M57           PLD2
#  16  P180_M57          PLPP1
#  17  P180_M57        PLA2G2A
#  18  P180_M57        PLA2G10
#  19  P180_M57       PLA2G12A
#  20  P180_M57          ENPP6
#  21  P180_M57        PLA2G4B
#  22  P180_M57  JMJD7-PLA2G4B
#  23  P180_M57         LPCAT1
#  24  P180_M57       PAFAH1B3
#  25  P180_M57          ENPP2
#  26  P180_M57         PLA2G6
#  27  P180_M57         LPCAT2
#  28  P180_M57       PLA2G12B
#  29  P180_M57        PLA2G2F
#  30  P180_M57         LPCAT4
#  31  P180_M57           AGPS
#  32  P180_M57          PLPP3,
#       ADNI_ID     gene
#  0   P180_M59   LPGAT1
#  1   P180_M59    ADPRM
#  2   P180_M59  PLA2G2E
#  3   P180_M59    PLPP2
#  4   P180_M59    CHPT1
#  ..       ...      ...
#  72  P180_M59    GPAT3
#  73  P180_M59    PCYT2
#  74  P180_M59   AGPAT3
#  75  P180_M59   LPCAT4
#  76  P180_M59     PGS1
#
#  [77 rows x 2 columns],
#       ADNI_ID     gene
#  0   P180_M61   LPGAT1
#  1   P180_M61    ADPRM
#  2   P180_M61  PLA2G2E
#  3   P180_M61    PLPP2
#  4   P180_M61    CHPT1
#  ..       ...      ...
#  72  P180_M61    GPAT3
#  73  P180_M61    PCYT2
#  74  P180_M61   AGPAT3
#  75  P180_M61   LPCAT4
#  76  P180_M61     PGS1
#
#  [77 rows x 2 columns],
#       ADNI_ID     gene
#  0   P180_M62   LPGAT1
#  1   P180_M62    ADPRM
#  2   P180_M62  PLA2G2E
#  3   P180_M62    PLPP2
#  4   P180_M62    CHPT1
#  ..       ...      ...
#  72  P180_M62    GPAT3
#  73  P180_M62    PCYT2
#  74  P180_M62   AGPAT3
#  75  P180_M62   LPCAT4
#  76  P180_M62     PGS1
#
#  [77 rows x 2 columns],
#       ADNI_ID     gene
#  0   P180_M31  ALDH9A1
#  1   P180_M31     ADH7
#  2   P180_M31    ACSL3
#  3   P180_M31  CYP4A22
#  4   P180_M31    ACSL6
#  5   P180_M31     ECI2
#  6   P180_M31  CYP4A11
#  7   P180_M31    CPT1B
#  8   P180_M31    CPT1A
#  9   P180_M31  ALDH3A2
#  10  P180_M31    HADHA
#  11  P180_M31    HADHB
#  12  P180_M31    ACOX3
#  13  P180_M31  ALDH7A1
#  14  P180_M31    ACOX1
#  15  P180_M31     ECI1
#  16  P180_M31   EHHADH
#  17  P180_M31  ALDH1B1
#  18  P180_M31    ACADM
#  19  P180_M31    ACAT2
#  20  P180_M31    ADH1A
#  21  P180_M31    ACAT1
#  22  P180_M31    ACAA2
#  23  P180_M31    ADH1C
#  24  P180_M31    ACSL5
#  25  P180_M31    ECHS1
#  26  P180_M31     ADH6
#  27  P180_M31    ALDH2
#  28  P180_M31     HADH
#  29  P180_M31    ACADL
#  30  P180_M31    ACAA1
#  31  P180_M31   ACADSB
#  32  P180_M31     CPT2
#  33  P180_M31    ACADS
#  34  P180_M31     GCDH
#  35  P180_M31    ACSL1
#  36  P180_M31    ADH1B
#  37  P180_M31    ACSL4
#  38  P180_M31    CPT1C
#  39  P180_M31   ACADVL
#  40  P180_M31     ADH4
#  41  P180_M31     ADH5]

# %%
compound_to_gene_df = pd.concat(compound_to_gene_list, ignore_index=True)
compound_to_gene_df
# Out:
#         ADNI_ID     gene
# 0      P180_M15  ALDH3B2
# 1      P180_M15    NAMPT
# 2      P180_M15     NSD1
# 3      P180_M15    DOT1L
# 4      P180_M15    ABCC4
# ...         ...      ...
# 19862  P180_M31    ACSL4
# 19863  P180_M31    CPT1C
# 19864  P180_M31   ACADVL
# 19865  P180_M31     ADH4
# 19866  P180_M31     ADH5
#
# [19867 rows x 2 columns]

# %%
compound_to_gene_df.set_index(['gene'], drop=False, inplace=True)

# %% [markdown]
# #### Read all metabQTLs (caution: large files!)

# %%
fia_metabQTL_all = pd.read_csv('metabQTL/fia-metabQTL-1_long.zip',
                                header=0, index_col=None, delimiter=",")

# %%
fia_metabQTL_all
# Out:
#                  snps       gene     statistic        pvalue       FDR  \
# 0            rs293172   P180_M16  7.690385e+00  1.313581e-12  0.000798
# 1            rs293170   P180_M16  6.842282e+00  1.497868e-10  0.011376
# 2            rs293173   P180_M16  6.842282e+00  1.497868e-10  0.011376
# 3            rs293174   P180_M16  6.842282e+00  1.497868e-10  0.011376
# 4            rs293175   P180_M16  6.842282e+00  1.497868e-10  0.011376
# ...               ...        ...           ...           ...       ...
# 607598695  rs71336711  P180_M122  4.077026e-09  1.000000e+00  1.000000
# 607598696  rs10424463  P180_M122  4.077026e-09  1.000000e+00  1.000000
# 607598697  rs10403676  P180_M122  4.077026e-09  1.000000e+00  1.000000
# 607598698  rs10419696  P180_M122  4.077026e-09  1.000000e+00  1.000000
# 607598699  rs56283027  P180_M122  4.077026e-09  1.000000e+00  1.000000
#
#                    beta
# 0          3.237272e-02
# 1          3.091165e-02
# 2          3.091165e-02
# 3          3.091165e-02
# 4          3.091165e-02
# ...                 ...
# 607598695  1.480980e-11
# 607598696  1.480980e-11
# 607598697  1.480980e-11
# 607598698  1.480980e-11
# 607598699  1.480980e-11
#
# [607598700 rows x 6 columns]

# %%
uplc_metabQTL_all = pd.read_csv('metabQTL/uplc-metabQTL-1.zip',
                                header=0, index_col=None, delimiter=",")

# %%
uplc_metabQTL_all

# %%
metabQTL_SNP_to_genes = compound_to_gene_df.join(eQTL,
                           how = 'inner', lsuffix='_x', rsuffix='_y')

# %%
metabQTL_SNP_to_genes
# Out:
#          ADNI_ID  chromosome  snpLocation        snpid          snpLocId  \
# AACS   P180_M193          12    124550051     rs902167  12:124550051_T_C
# AACS   P180_M193          12    124550341    rs1686725  12:124550341_T_G
# AACS   P180_M193          12    124551229    rs1686726  12:124551229_A_C
# AACS   P180_M193          12    124552125  rs113624010  12:124552125_G_A
# AACS   P180_M193          12    124552349   rs80081406  12:124552349_C_T
# ...          ...         ...          ...          ...               ...
# WNT9A  P180_M197           1    229133819   rs61825092   1:229133819_G_A
# WNT9A  P180_M197           1    229134166   rs61825093   1:229134166_G_A
# WNT9A  P180_M197           1    229134471     rs630716   1:229134471_A_G
# WNT9A  P180_M197           1    229134840   rs72760181   1:229134840_G_A
# WNT9A  P180_M197           1    229135031   rs12120173   1:229135031_T_G
#
#                   gene geneSymbol  statistic    pvalue       FDR      beta A1  \
# AACS   ENSG00000081760       AACS   1.807933  0.070617  0.505805  0.068535  T
# AACS   ENSG00000081760       AACS   1.088867  0.276212  0.791843  0.046814  T
# AACS   ENSG00000081760       AACS   1.781607  0.074813  0.518478  0.067640  A
# AACS   ENSG00000081760       AACS  -1.075117  0.282323  0.796150 -0.054735  G
# AACS   ENSG00000081760       AACS  -1.030249  0.302893  0.809551 -0.052422  C
# ...                ...        ...        ...       ...       ...       ... ..
# WNT9A  ENSG00000143816      WNT9A  -0.250360  0.802309  0.971560 -0.048691  G
# WNT9A  ENSG00000143816      WNT9A  -0.251780  0.801211  0.971372 -0.048976  G
# WNT9A  ENSG00000143816      WNT9A  -0.925373  0.354772  0.837536 -0.055660  A
# WNT9A  ENSG00000143816      WNT9A   1.662608  0.096391  0.569502  0.273474  G
# WNT9A  ENSG00000143816      WNT9A  -1.977619  0.047972  0.423483 -0.108190  T
#
#       A2    A2freq expressionIncreasingAllele  strand     geneBiotype  \
# AACS   C  0.604360                          C     1.0  protein_coding
# AACS   G  0.764966                          G     1.0  protein_coding
# AACS   C  0.604339                          C     1.0  protein_coding
# AACS   A  0.160103                          G     1.0  protein_coding
# AACS   T  0.160254                          C     1.0  protein_coding
# ...   ..       ...                        ...     ...             ...
# WNT9A  A  0.010579                          G    -1.0  protein_coding
# WNT9A  A  0.010571                          G    -1.0  protein_coding
# WNT9A  G  0.757571                          A    -1.0  protein_coding
# WNT9A  A  0.021260                          A    -1.0  protein_coding
# WNT9A  G  0.281176                          T    -1.0  protein_coding
#
#        geneStartPosition  geneEndPosition
# AACS         125065379.0      125143333.0
# AACS         125065379.0      125143333.0
# AACS         125065379.0      125143333.0
# AACS         125065379.0      125143333.0
# AACS         125065379.0      125143333.0
# ...                  ...              ...
# WNT9A        227918656.0      227947898.0
# WNT9A        227918656.0      227947898.0
# WNT9A        227918656.0      227947898.0
# WNT9A        227918656.0      227947898.0
# WNT9A        227918656.0      227947898.0
#
# [78990008 rows x 19 columns]

# %%
metabQTL_SNP_to_genes.set_index(['ADNI_ID', 'snpid'], drop=False, inplace=True)

# %%
fia_metabQTL_all.set_index(['gene', 'snps'], drop=False, inplace=True)

# %%
fia_metabQTL_all.index.names = ['ADNI_ID', 'snpid']

# %%
metabQTL_SNP_to_genes.sort_index(inplace=True)

# %%
fia_metabQTL_all.sort_index(inplace=True)

# %%
fia_metabQTL_overlapping_eQTL = fia_metabQTL_all.join(metabQTL_SNP_to_genes, 
           how='inner', lsuffix='_x', rsuffix='_y')

# %%
fia_metabQTL_overlapping_eQTL
# Out:
#                            snps    gene_x  statistic_x  pvalue_x     FDR_x  \
# ADNI_ID  snpid
# P180_M31 rs10000018  rs10000018  P180_M31    -2.732361  0.006982  0.999996
#          rs10000018  rs10000018  P180_M31    -2.732361  0.006982  0.999996
#          rs10000034  rs10000034  P180_M31    -1.207171  0.229115  0.999996
#          rs10000067  rs10000067  P180_M31    -0.960513  0.338220  0.999996
#          rs10000067  rs10000067  P180_M31    -0.960513  0.338220  0.999996
# ...                         ...       ...          ...       ...       ...
# P180_M62 rs9999788    rs9999788  P180_M62    -0.118037  0.906183  0.999996
#          rs999979      rs999979  P180_M62     0.476060  0.634669  0.999996
#          rs9999824    rs9999824  P180_M62    -1.308057  0.192696  0.999996
#          rs9999830    rs9999830  P180_M62     1.294146  0.197445  0.999996
#          rs9999909    rs9999909  P180_M62    -0.914158  0.361984  0.999996
#
#                        beta_x   ADNI_ID  chromosome  snpLocation       snpid  \
# ADNI_ID  snpid
# P180_M31 rs10000018 -0.008236  P180_M31           4    100458448  rs10000018
#          rs10000018 -0.008236  P180_M31           4    100458448  rs10000018
#          rs10000034 -0.005554  P180_M31           4      8174883  rs10000034
#          rs10000067 -0.003402  P180_M31           4    100296476  rs10000067
#          rs10000067 -0.003402  P180_M31           4    100296476  rs10000067
# ...                       ...       ...         ...          ...         ...
# P180_M62 rs9999788  -0.053725  P180_M62           4    109921572   rs9999788
#          rs999979    0.159791  P180_M62           3    170832832    rs999979
#          rs9999824  -0.454538  P180_M62           4    110935774   rs9999824
#          rs9999830   0.668025  P180_M62           4    109708724   rs9999830
#          rs9999909  -0.323681  P180_M62           4     84182715   rs9999909
#
#                      ...     FDR_y    beta_y A1  A2    A2freq  \
# ADNI_ID  snpid       ...
# P180_M31 rs10000018  ...  0.850325 -0.047233  A   G  0.294417
#          rs10000018  ...  0.941563  0.017465  A   G  0.294417
#          rs10000034  ...  0.985055  0.008433  T   G  0.098137
#          rs10000067  ...  0.943883 -0.025708  T   C  0.194369
#          rs10000067  ...  0.797216 -0.046855  T   C  0.194369
# ...                  ...       ...       ... ..  ..       ...
# P180_M62 rs9999788   ...  0.972345  0.011363  C   T  0.857350
#          rs999979    ...  0.696261 -0.048334  C   T  0.575631
#          rs9999824   ...  0.574103 -0.066085  A   C  0.299302
#          rs9999830   ...  0.994642  0.002756  A   G  0.138399
#          rs9999909   ...  0.868960 -0.029870  C   G  0.345358
#
#                      expressionIncreasingAllele  strand     geneBiotype  \
# ADNI_ID  snpid
# P180_M31 rs10000018                           A    -1.0  protein_coding
#          rs10000018                           G    -1.0  protein_coding
#          rs10000034                           G    -1.0  protein_coding
#          rs10000067                           T    -1.0  protein_coding
#          rs10000067                           T    -1.0  protein_coding
# ...                                         ...     ...             ...
# P180_M62 rs9999788                            T    -1.0  protein_coding
#          rs999979                             C    -1.0  protein_coding
#          rs9999824                            A    -1.0  protein_coding
#          rs9999830                            G    -1.0  protein_coding
#          rs9999909                            C     1.0  protein_coding
#
#                     geneStartPosition  geneEndPosition
# ADNI_ID  snpid
# P180_M31 rs10000018        99304964.0       99321401.0
#          rs10000018        99070978.0       99088801.0
#          rs10000034         8366282.0        8440723.0
#          rs10000067        99304964.0       99321401.0
#          rs10000067        99070978.0       99088801.0
# ...                               ...              ...
# P180_M62 rs9999788        109709989.0      109730077.0
#          rs999979         171600405.0      171810950.0
#          rs9999824        109709989.0      109730077.0
#          rs9999830        109709989.0      109730077.0
#          rs9999909         83535914.0       83605875.0
#
# [904407 rows x 25 columns]

# %%
fia_metabQTL_overlapping_eQTL_idxmin = fia_metabQTL_overlapping_eQTL.reset_index(drop=True)

# %%
fia_metabQTL_overlapping_eQTL_idxmin = fia_metabQTL_overlapping_eQTL_idxmin.loc[
    fia_metabQTL_overlapping_eQTL_idxmin.groupby(['snps','geneSymbol']).pvalue_x.idxmin()].reset_index(drop=True)

# %%
fia_metabQTL_overlapping_eQTL_idxmin
# Out:
#               snps    gene_x  statistic_x  pvalue_x     FDR_x    beta_x  \
# 0       rs10000005  P180_M59    -2.383190  0.018314  0.999996 -2.262149
# 1       rs10000005  P180_M59    -2.383190  0.018314  0.999996 -2.262149
# 2       rs10000012  P180_M59    -1.645260  0.101843  0.999996 -2.239805
# 3       rs10000015  P180_M62     1.681095  0.094660  0.999996  1.440465
# 4       rs10000017  P180_M62    -1.159114  0.248105  0.999996 -0.484103
# ...            ...       ...          ...       ...       ...       ...
# 382880   rs9999909  P180_M62    -0.914158  0.361984  0.999996 -0.323681
# 382881   rs9999976  P180_M31    -0.686366  0.493458  0.999996 -0.002443
# 382882   rs9999976  P180_M31    -0.686366  0.493458  0.999996 -0.002443
# 382883   rs9999995  P180_M31    -0.942792  0.347182  0.999996 -0.005681
# 382884   rs9999995  P180_M57    -1.202861  0.230774  0.999996 -0.204481
#
#          ADNI_ID  chromosome  snpLocation       snpid  ...     FDR_y  \
# 0       P180_M59           4     85161558  rs10000005  ...  0.860259
# 1       P180_M59           4     85161558  rs10000005  ...  0.844547
# 2       P180_M59           4      1357325  rs10000012  ...  0.873740
# 3       P180_M62           4     84143987  rs10000015  ...  0.446931
# 4       P180_M62           4     84778125  rs10000017  ...  0.777392
# ...          ...         ...          ...         ...  ...       ...
# 382880  P180_M62           4     84182715   rs9999909  ...  0.868960
# 382881  P180_M31           4    100296362   rs9999976  ...  0.943843
# 382882  P180_M31           4    100296362   rs9999976  ...  0.793215
# 382883  P180_M31           4    185171608   rs9999995  ...  0.842803
# 382884  P180_M57           4    185171608   rs9999995  ...  0.747300
#
#           beta_y A1  A2    A2freq  expressionIncreasingAllele  strand  \
# 0       0.029990  G   A  0.544044                           A     1.0
# 1      -0.032557  G   A  0.544044                           G     1.0
# 2      -0.039266  C   G  0.141901                           C    -1.0
# 3      -0.161501  A   G  0.059053                           A     1.0
# 4      -0.049897  C   T  0.229813                           C     1.0
# ...          ... ..  ..       ...                         ...     ...
# 382880 -0.029870  C   G  0.345358                           C     1.0
# 382881 -0.025792  T   C  0.193930                           T    -1.0
# 382882 -0.047583  T   C  0.193930                           T    -1.0
# 382883 -0.058542  A   G  0.078814                           A    -1.0
# 382884 -0.078682  A   G  0.078814                           A    -1.0
#
#            geneBiotype geneStartPosition  geneEndPosition
# 0       protein_coding        84582979.0       84651338.0
# 1       protein_coding        83535914.0       83605875.0
# 2       protein_coding          958887.0         986895.0
# 3       protein_coding        83535914.0       83605875.0
# 4       protein_coding        84582979.0       84651338.0
# ...                ...               ...              ...
# 382880  protein_coding        83535914.0       83605875.0
# 382881  protein_coding        99304964.0       99321401.0
# 382882  protein_coding        99070978.0       99088801.0
# 382883  protein_coding       184755595.0      184826818.0
# 382884  protein_coding       184088706.0      184221230.0
#
# [382885 rows x 25 columns]

# %%
fia_metabQTL_overlapping_eQTL_idxmin.drop(['gene_x','gene_y'], axis=1, inplace=True)

# %%
fia_metabQTL_overlapping_eQTL_idxmin
# Out:
#               snps  statistic_x  pvalue_x     FDR_x    beta_x   ADNI_ID  \
# 0       rs10000005    -2.383190  0.018314  0.999996 -2.262149  P180_M59
# 1       rs10000005    -2.383190  0.018314  0.999996 -2.262149  P180_M59
# 2       rs10000012    -1.645260  0.101843  0.999996 -2.239805  P180_M59
# 3       rs10000015     1.681095  0.094660  0.999996  1.440465  P180_M62
# 4       rs10000017    -1.159114  0.248105  0.999996 -0.484103  P180_M62
# ...            ...          ...       ...       ...       ...       ...
# 382880   rs9999909    -0.914158  0.361984  0.999996 -0.323681  P180_M62
# 382881   rs9999976    -0.686366  0.493458  0.999996 -0.002443  P180_M31
# 382882   rs9999976    -0.686366  0.493458  0.999996 -0.002443  P180_M31
# 382883   rs9999995    -0.942792  0.347182  0.999996 -0.005681  P180_M31
# 382884   rs9999995    -1.202861  0.230774  0.999996 -0.204481  P180_M57
#
#         chromosome  snpLocation       snpid         snpLocId  ...     FDR_y  \
# 0                4     85161558  rs10000005   4:85161558_G_A  ...  0.860259
# 1                4     85161558  rs10000005   4:85161558_G_A  ...  0.844547
# 2                4      1357325  rs10000012    4:1357325_C_G  ...  0.873740
# 3                4     84143987  rs10000015   4:84143987_A_G  ...  0.446931
# 4                4     84778125  rs10000017   4:84778125_C_T  ...  0.777392
# ...            ...          ...         ...              ...  ...       ...
# 382880           4     84182715   rs9999909   4:84182715_C_G  ...  0.868960
# 382881           4    100296362   rs9999976  4:100296362_T_C  ...  0.943843
# 382882           4    100296362   rs9999976  4:100296362_T_C  ...  0.793215
# 382883           4    185171608   rs9999995  4:185171608_A_G  ...  0.842803
# 382884           4    185171608   rs9999995  4:185171608_A_G  ...  0.747300
#
#           beta_y  A1  A2    A2freq expressionIncreasingAllele strand  \
# 0       0.029990   G   A  0.544044                          A    1.0
# 1      -0.032557   G   A  0.544044                          G    1.0
# 2      -0.039266   C   G  0.141901                          C   -1.0
# 3      -0.161501   A   G  0.059053                          A    1.0
# 4      -0.049897   C   T  0.229813                          C    1.0
# ...          ...  ..  ..       ...                        ...    ...
# 382880 -0.029870   C   G  0.345358                          C    1.0
# 382881 -0.025792   T   C  0.193930                          T   -1.0
# 382882 -0.047583   T   C  0.193930                          T   -1.0
# 382883 -0.058542   A   G  0.078814                          A   -1.0
# 382884 -0.078682   A   G  0.078814                          A   -1.0
#
#            geneBiotype geneStartPosition  geneEndPosition
# 0       protein_coding        84582979.0       84651338.0
# 1       protein_coding        83535914.0       83605875.0
# 2       protein_coding          958887.0         986895.0
# 3       protein_coding        83535914.0       83605875.0
# 4       protein_coding        84582979.0       84651338.0
# ...                ...               ...              ...
# 382880  protein_coding        83535914.0       83605875.0
# 382881  protein_coding        99304964.0       99321401.0
# 382882  protein_coding        99070978.0       99088801.0
# 382883  protein_coding       184755595.0      184826818.0
# 382884  protein_coding       184088706.0      184221230.0
#
# [382885 rows x 23 columns]

# %%
fia_metabQTL_overlapping_eQTL.to_csv("analysis_using_meta_eQTL/fia_metabQTL_overlapping_eQTL.csv", index=False)

# %%
uplc_metabQTL_all.set_index(['gene', 'snps'], drop=False, inplace=True)

# %%
uplc_metabQTL_all.index.names = ['ADNI_ID', 'snpid']

# %%
uplc_metabQTL_all.sort_index(inplace=True)

# %%
uplc_metabQTL_overlapping_eQTL = uplc_metabQTL_all.join(metabQTL_SNP_to_genes, 
           how='inner', lsuffix='_x', rsuffix='_y')

# %%
uplc_metabQTL_overlapping_eQTL

# %%
uplc_metabQTL_overlapping_eQTL_idxmin = uplc_metabQTL_overlapping_eQTL.reset_index(drop=True)

# %%
uplc_metabQTL_overlapping_eQTL_idxmin = uplc_metabQTL_overlapping_eQTL_idxmin.loc[
    uplc_metabQTL_overlapping_eQTL_idxmin.groupby(['snps','gene_x']).pvalue_x.idxmin()].reset_index(drop=True)

# %%
uplc_metabQTL_overlapping_eQTL_idxmin

# %%
uplc_metabQTL_overlapping_eQTL_idxmin.drop(['gene','gene_x','gene_y'], axis=1, inplace=True)

# %%
uplc_metabQTL_overlapping_eQTL_idxmin

# %%
uplc_metabQTL_overlapping_eQTL_idxmin.to_csv("analysis_using_meta_eQTL/uplc_metabQTL_overlapping_eQTL.csv", index=False)

# %%
uplc_metabQTL_overlapping_eQTL_idxmin = pd.read_csv("analysis_using_meta_eQTL/uplc_metabQTL_overlapping_eQTL.csv", header=0, index_col=None, delimiter=",")

# %%
metabQTL_overlapping_eQTL_idxmin = pd.concat(
    [uplc_metabQTL_overlapping_eQTL_idxmin, fia_metabQTL_overlapping_eQTL_idxmin],
    axis=0,
    ignore_index=True)

# %%
metabQTL_overlapping_eQTL_idxmin
# Out:
#                snps  statistic_x  pvalue_x     FDR_x    beta_x    ADNI_ID  \
# 0        rs10000003     2.179230  0.030750  0.999937  2.626286   P180_M14
# 1        rs10000003     1.329355  0.185588  0.999937  0.777456  P180_M193
# 2        rs10000003     1.329355  0.185588  0.999937  0.777456  P180_M193
# 3        rs10000003     2.179230  0.030750  0.999937  2.626286   P180_M14
# 4        rs10000005     2.215504  0.028111  0.999937  7.594640  P180_M167
# ...             ...          ...       ...       ...       ...        ...
# 3225691   rs9999909    -0.914158  0.361984  0.999996 -0.323681   P180_M62
# 3225692   rs9999976    -0.686366  0.493458  0.999996 -0.002443   P180_M31
# 3225693   rs9999976    -0.686366  0.493458  0.999996 -0.002443   P180_M31
# 3225694   rs9999995    -0.942792  0.347182  0.999996 -0.005681   P180_M31
# 3225695   rs9999995    -1.202861  0.230774  0.999996 -0.204481   P180_M57
#
#          chromosome  snpLocation       snpid         snpLocId  ...     FDR_y  \
# 0                 4     57561647  rs10000003   4:57561647_A_G  ...  0.639259
# 1                 4     57561647  rs10000003   4:57561647_A_G  ...  0.782251
# 2                 4     57561647  rs10000003   4:57561647_A_G  ...  0.779798
# 3                 4     57561647  rs10000003   4:57561647_A_G  ...  0.586852
# 4                 4     85161558  rs10000005   4:85161558_G_A  ...  0.860259
# ...             ...          ...         ...              ...  ...       ...
# 3225691           4     84182715   rs9999909   4:84182715_C_G  ...  0.868960
# 3225692           4    100296362   rs9999976  4:100296362_T_C  ...  0.943843
# 3225693           4    100296362   rs9999976  4:100296362_T_C  ...  0.793215
# 3225694           4    185171608   rs9999995  4:185171608_A_G  ...  0.842803
# 3225695           4    185171608   rs9999995  4:185171608_A_G  ...  0.747300
#
#            beta_y  A1  A2    A2freq expressionIncreasingAllele strand  \
# 0        0.058436   A   G  0.700927                          G   -1.0
# 1       -0.043648   A   G  0.700927                          A    1.0
# 2        0.043499   A   G  0.700927                          G    1.0
# 3        0.064515   A   G  0.700927                          G   -1.0
# 4        0.029990   G   A  0.544044                          A    1.0
# ...           ...  ..  ..       ...                        ...    ...
# 3225691 -0.029870   C   G  0.345358                          C    1.0
# 3225692 -0.025792   T   C  0.193930                          T   -1.0
# 3225693 -0.047583   T   C  0.193930                          T   -1.0
# 3225694 -0.058542   A   G  0.078814                          A   -1.0
# 3225695 -0.078682   A   G  0.078814                          A   -1.0
#
#             geneBiotype geneStartPosition  geneEndPosition
# 0        protein_coding        56338287.0       56387508.0
# 1        protein_coding        56435741.0       56464579.0
# 2        protein_coding        56977722.0       57031168.0
# 3        protein_coding        56393362.0       56435615.0
# 4        protein_coding        84582979.0       84651338.0
# ...                 ...               ...              ...
# 3225691  protein_coding        83535914.0       83605875.0
# 3225692  protein_coding        99304964.0       99321401.0
# 3225693  protein_coding        99070978.0       99088801.0
# 3225694  protein_coding       184755595.0      184826818.0
# 3225695  protein_coding       184088706.0      184221230.0
#
# [3225696 rows x 23 columns]

# %%
metabQTL_overlapping_eQTL_idxmin = metabQTL_overlapping_eQTL_idxmin.loc[
    metabQTL_overlapping_eQTL_idxmin.groupby(['snps','geneSymbol']).pvalue_x.idxmin()].reset_index(drop=True)

# %%
metabQTL_overlapping_eQTL_idxmin
# Out:
#                snps  statistic_x  pvalue_x     FDR_x     beta_x    ADNI_ID  \
# 0        rs10000003     2.179230  0.030750  0.999937   2.626286   P180_M14
# 1        rs10000003     1.329355  0.185588  0.999937   0.777456  P180_M193
# 2        rs10000003     1.329355  0.185588  0.999937   0.777456  P180_M193
# 3        rs10000003     2.179230  0.030750  0.999937   2.626286   P180_M14
# 4        rs10000005    -2.383190  0.018314  0.999996  -2.262149   P180_M59
# ...             ...          ...       ...       ...        ...        ...
# 2925854   rs9999976     2.321265  0.021511  0.999937   4.875438  P180_M196
# 2925855   rs9999976    -2.565780  0.011195  0.999937  -3.551833   P180_M14
# 2925856   rs9999981     2.779724  0.006081  0.999937  12.374678   P180_M26
# 2925857   rs9999995    -0.942792  0.347182  0.999996  -0.005681   P180_M31
# 2925858   rs9999995    -1.202861  0.230774  0.999996  -0.204481   P180_M57
#
#          chromosome  snpLocation       snpid         snpLocId  ...     FDR_y  \
# 0                 4     57561647  rs10000003   4:57561647_A_G  ...  0.639259
# 1                 4     57561647  rs10000003   4:57561647_A_G  ...  0.782251
# 2                 4     57561647  rs10000003   4:57561647_A_G  ...  0.779798
# 3                 4     57561647  rs10000003   4:57561647_A_G  ...  0.586852
# 4                 4     85161558  rs10000005   4:85161558_G_A  ...  0.860259
# ...             ...          ...         ...              ...  ...       ...
# 2925854           4    100296362   rs9999976  4:100296362_T_C  ...  0.793215
# 2925855           4    100296362   rs9999976  4:100296362_T_C  ...  0.576729
# 2925856           4    139575905   rs9999981  4:139575905_A_G  ...  0.715943
# 2925857           4    185171608   rs9999995  4:185171608_A_G  ...  0.842803
# 2925858           4    185171608   rs9999995  4:185171608_A_G  ...  0.747300
#
#            beta_y  A1  A2    A2freq expressionIncreasingAllele strand  \
# 0        0.058436   A   G  0.700927                          G   -1.0
# 1       -0.043648   A   G  0.700927                          A    1.0
# 2        0.043499   A   G  0.700927                          G    1.0
# 3        0.064515   A   G  0.700927                          G   -1.0
# 4        0.029990   G   A  0.544044                          A    1.0
# ...           ...  ..  ..       ...                        ...    ...
# 2925854 -0.047583   T   C  0.193930                          T   -1.0
# 2925855 -0.072251   T   C  0.193930                          T   -1.0
# 2925856  0.049620   A   G  0.624530                          G   -1.0
# 2925857 -0.058542   A   G  0.078814                          A   -1.0
# 2925858 -0.078682   A   G  0.078814                          A   -1.0
#
#             geneBiotype geneStartPosition  geneEndPosition
# 0        protein_coding        56338287.0       56387508.0
# 1        protein_coding        56435741.0       56464579.0
# 2        protein_coding        56977722.0       57031168.0
# 3        protein_coding        56393362.0       56435615.0
# 4        protein_coding        84582979.0       84651338.0
# ...                 ...               ...              ...
# 2925854  protein_coding        99070978.0       99088801.0
# 2925855  protein_coding        98871684.0       98930637.0
# 2925856  protein_coding       139495941.0      139606699.0
# 2925857  protein_coding       184755595.0      184826818.0
# 2925858  protein_coding       184088706.0      184221230.0
#
# [2925859 rows x 23 columns]

# %%
metabQTL_overlapping_eQTL_idxmin.to_csv("analysis_using_meta_eQTL/metabQTL_overlapping_eQTL.csv", index=False)

# %% [markdown]
# ### methylQTL
# - Used data from 209 ADNI 2/GO controls
# - Used Bioconductor package data to match probes to genes
# - Used an annotation file from Illumina which maps CpG’s to genes
# - Aggregated probes to create gene-level signals (mean)
# - methylQTL performed on a gene level

# %%
mQTL = pd.read_csv("Filtered eQTL and mQTL/controls.txt", header=0, index_col=None, delimiter=",")

# %%
mQTL
# Out:
#                 snps                                          gene  statistic  \
# 0          rs2069978                                GPX4;GPX4;GPX4   9.889386
# 1          rs2069978                      GPX4;GPX4;GPX4;GPX4;GPX4   9.607171
# 2          rs2069984                                GPX4;GPX4;GPX4   9.085744
# 3          rs2069987                                GPX4;GPX4;GPX4   9.085744
# 4         rs60428566                                GPX4;GPX4;GPX4   9.085744
# ...              ...                                           ...        ...
# 30888009   rs1355106  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888010   rs1355107  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888011  rs12499737  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888012  rs12504629  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888013  rs12500602  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
#
#                 pvalue           FDR      beta
# 0         6.223929e-19  1.847805e-08  0.078782
# 1         4.019592e-18  5.966828e-08  0.109791
# 2         1.201035e-16  5.942866e-07  0.070466
# 3         1.201035e-16  5.942866e-07  0.070466
# 4         1.201035e-16  5.942866e-07  0.070466
# ...                ...           ...       ...
# 30888009  1.000000e-03  9.611729e-01 -0.013573
# 30888010  1.000000e-03  9.611729e-01 -0.013573
# 30888011  1.000000e-03  9.611729e-01 -0.013573
# 30888012  1.000000e-03  9.611729e-01 -0.013573
# 30888013  1.000000e-03  9.611729e-01 -0.013573
#
# [30888014 rows x 6 columns]

# %%
gene_group_to_gene = pd.DataFrame(columns=['gene', 'Symbol'])
unique_gene_lists = np.unique(mQTL.gene)
for gene_list in tqdm(unique_gene_lists):
    genes = list(set(gene_list.split(';')))
    for i in range(len(genes)):
        gene_group_to_gene = gene_group_to_gene.append(
            pd.DataFrame([[gene_list, genes[i]]], columns=['gene', 'Symbol']), ignore_index=True)
gene_group_to_gene
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4793.0), HTML(value='')))
#                          gene   Symbol
# 0                  AA06;ASIC2    ASIC2
# 1                  AA06;ASIC2     AA06
# 2                        AACS     AACS
# 3                   AACS;AACS     AACS
# 4                       AACSL    AACSL
# ...                       ...      ...
# 6763                    ZPLD1    ZPLD1
# 6764          ZSCAN29;TUBGCP4  TUBGCP4
# 6765          ZSCAN29;TUBGCP4  ZSCAN29
# 6766  ZSCAN29;TUBGCP4;TUBGCP4  TUBGCP4
# 6767  ZSCAN29;TUBGCP4;TUBGCP4  ZSCAN29
#
# [6768 rows x 2 columns]

# %%
gene_group_to_gene.set_index('Symbol', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-2bd0c70c2c81> in <module>
# ----> 1 gene_group_to_gene.set_index('Symbol', inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Symbol'] are in the columns"

# %%
mQTL_SNP_to_genes = gene_group_to_gene.join(eQTL,
                           how = 'inner', lsuffix='_x', rsuffix='_y')

# %%
mQTL_SNP_to_genes
# Out:
#               gene_x  chromosome  snpLocation       snpid         snpLocId  \
# A1BG            A1BG          19     57856955  rs10406132  19:57856955_T_C
# A1BG            A1BG          19     57857105   rs1544494  19:57857105_C_T
# A1BG            A1BG          19     57857142  rs73063216  19:57857142_C_A
# A1BG            A1BG          19     57857202  rs73063217  19:57857202_T_C
# A1BG            A1BG          19     57857948   rs2159030  19:57857948_T_C
# ...              ...         ...          ...         ...              ...
# ZZZ3  ZZZ3;ZZZ3;ZZZ3           1     79147922  rs72935685   1:79147922_T_C
# ZZZ3  ZZZ3;ZZZ3;ZZZ3           1     79147976  rs17102049   1:79147976_G_A
# ZZZ3  ZZZ3;ZZZ3;ZZZ3           1     79148288  rs17398682   1:79148288_C_T
# ZZZ3  ZZZ3;ZZZ3;ZZZ3           1     79148633  rs17102051   1:79148633_A_G
# ZZZ3  ZZZ3;ZZZ3;ZZZ3           1     79148645  rs17102054   1:79148645_A_G
#
#                gene_y geneSymbol  statistic    pvalue       FDR      beta A1  \
# A1BG  ENSG00000121410       A1BG   0.566644  0.570956  0.934629  0.031715  T
# A1BG  ENSG00000121410       A1BG  -0.716156  0.473895  0.908752 -0.037303  C
# A1BG  ENSG00000121410       A1BG  -1.603183  0.108894  0.642906 -0.169437  C
# A1BG  ENSG00000121410       A1BG  -1.463256  0.143397  0.698797 -0.153530  T
# A1BG  ENSG00000121410       A1BG  -0.610235  0.541706  0.927423 -0.037554  T
# ...               ...        ...        ...       ...       ...       ... ..
# ZZZ3  ENSG00000036549       ZZZ3   0.330917  0.740707  0.960569  0.023024  T
# ZZZ3  ENSG00000036549       ZZZ3   0.330749  0.740834  0.960602  0.023012  G
# ZZZ3  ENSG00000036549       ZZZ3   0.944410  0.344960  0.832257  0.036983  C
# ZZZ3  ENSG00000036549       ZZZ3   0.462890  0.643443  0.939693  0.032269  A
# ZZZ3  ENSG00000036549       ZZZ3   0.445668  0.655837  0.942623  0.030859  A
#
#      A2    A2freq expressionIncreasingAllele  strand     geneBiotype  \
# A1BG  C  0.325755                          C    -1.0  protein_coding
# A1BG  T  0.530138                          C    -1.0  protein_coding
# A1BG  A  0.081109                          C    -1.0  protein_coding
# A1BG  C  0.081111                          T    -1.0  protein_coding
# A1BG  C  0.764907                          T    -1.0  protein_coding
# ...  ..       ...                        ...     ...             ...
# ZZZ3  C  0.094893                          C    -1.0  protein_coding
# ZZZ3  A  0.094874                          A    -1.0  protein_coding
# ZZZ3  T  0.323603                          T    -1.0  protein_coding
# ZZZ3  G  0.094833                          G    -1.0  protein_coding
# ZZZ3  G  0.095808                          G    -1.0  protein_coding
#
#       geneStartPosition  geneEndPosition
# A1BG         58345178.0       58353499.0
# A1BG         58345178.0       58353499.0
# A1BG         58345178.0       58353499.0
# A1BG         58345178.0       58353499.0
# A1BG         58345178.0       58353499.0
# ...                 ...              ...
# ZZZ3         77562416.0       77683419.0
# ZZZ3         77562416.0       77683419.0
# ZZZ3         77562416.0       77683419.0
# ZZZ3         77562416.0       77683419.0
# ZZZ3         77562416.0       77683419.0
#
# [299615069 rows x 19 columns]

# %%
mQTL_SNP_to_genes.set_index(['gene_x', 'snpid'], drop=False, inplace=True)

# %%
mQTL.set_index(['gene', 'snps'], drop=False, inplace=True)

# %%
mQTL_SNP_to_genes.index.names = ['gene', 'snps']

# %%
mQTL_SNP_to_genes.sort_index(inplace=True)

# %%
mQTL.sort_index(inplace=True)

# %%
mQTL_overlapping_eQTL = mQTL.join(mQTL_SNP_to_genes, 
           how='inner', lsuffix='_x', rsuffix='_y')

# %%
mQTL_overlapping_eQTL
# Out:
#                                     snps               gene  statistic_x  \
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512  rs61919512  A2ML1;A2ML1;A2ML1    -4.157133
# AACS              rs1971321    rs1971321               AACS    -4.020785
#                   rs75675338  rs75675338               AACS    -4.183230
#                   rs78271556  rs78271556               AACS    -3.984283
#                   rs78772671  rs78772671               AACS    -4.183230
# ...                                  ...                ...          ...
# ZXDC              rs7620198    rs7620198               ZXDC    -4.547077
#                   rs77826798  rs77826798               ZXDC    -4.123829
#                   rs78007488  rs78007488               ZXDC    -4.123829
#                   rs9864330    rs9864330               ZXDC    -4.289584
#                   rs999468      rs999468               ZXDC    -4.123829
#
#                               pvalue_x     FDR_x    beta_x             gene_x  \
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512  0.000048  0.832931 -0.034387  A2ML1;A2ML1;A2ML1
# AACS              rs1971321   0.000083  0.867863 -0.012643               AACS
#                   rs75675338  0.000044  0.825360 -0.012431               AACS
#                   rs78271556  0.000096  0.876034 -0.012156               AACS
#                   rs78772671  0.000044  0.825360 -0.012431               AACS
# ...                                ...       ...       ...                ...
# ZXDC              rs7620198   0.000010  0.695064 -0.017365               ZXDC
#                   rs77826798  0.000055  0.842099 -0.018881               ZXDC
#                   rs78007488  0.000055  0.842099 -0.018881               ZXDC
#                   rs9864330   0.000028  0.792448 -0.016432               ZXDC
#                   rs999468    0.000055  0.842099 -0.018881               ZXDC
#
#                               chromosome  snpLocation       snpid  ...  \
# gene              snps                                             ...
# A2ML1;A2ML1;A2ML1 rs61919512          12      9030678  rs61919512  ...
# AACS              rs1971321           12    124693529   rs1971321  ...
#                   rs75675338          12    124683876  rs75675338  ...
#                   rs78271556          12    124686868  rs78271556  ...
#                   rs78772671          12    124672811  rs78772671  ...
# ...                                  ...          ...         ...  ...
# ZXDC              rs7620198            3    127095546   rs7620198  ...
#                   rs77826798           3    127176591  rs77826798  ...
#                   rs78007488           3    127176696  rs78007488  ...
#                   rs9864330            3    127097657   rs9864330  ...
#                   rs999468             3    127173559    rs999468  ...
#
#                                  FDR_y    beta_y A1  A2    A2freq  \
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512  0.833074 -0.060928  C   G  0.096253
# AACS              rs1971321   0.243394 -0.170759  C   T  0.076277
#                   rs75675338  0.143331 -0.196451  C   G  0.076026
#                   rs78271556  0.150354 -0.194953  G   A  0.076246
#                   rs78772671  0.275519 -0.170800  C   T  0.075854
# ...                                ...       ... ..  ..       ...
# ZXDC              rs7620198   0.899599  0.024481  A   G  0.727734
#                   rs77826798  0.826746 -0.042354  A   G  0.184010
#                   rs78007488  0.826896 -0.042332  T   G  0.184008
#                   rs9864330   0.863125  0.030669  G   C  0.727489
#                   rs999468    0.818820 -0.043363  C   A  0.184226
#
#                               expressionIncreasingAllele  strand  \
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512                           C     1.0
# AACS              rs1971321                            C     1.0
#                   rs75675338                           C     1.0
#                   rs78271556                           G     1.0
#                   rs78772671                           C     1.0
# ...                                                  ...     ...
# ZXDC              rs7620198                            G    -1.0
#                   rs77826798                           A    -1.0
#                   rs78007488                           T    -1.0
#                   rs9864330                            C    -1.0
#                   rs999468                             C    -1.0
#
#                                  geneBiotype geneStartPosition  \
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512  protein_coding         8822472.0
# AACS              rs1971321   protein_coding       125065379.0
#                   rs75675338  protein_coding       125065379.0
#                   rs78271556  protein_coding       125065379.0
#                   rs78772671  protein_coding       125065379.0
# ...                                      ...               ...
# ZXDC              rs7620198   protein_coding       126437601.0
#                   rs77826798  protein_coding       126437601.0
#                   rs78007488  protein_coding       126437601.0
#                   rs9864330   protein_coding       126437601.0
#                   rs999468    protein_coding       126437601.0
#
#                               geneEndPosition
# gene              snps
# A2ML1;A2ML1;A2ML1 rs61919512        8887001.0
# AACS              rs1971321       125143333.0
#                   rs75675338      125143333.0
#                   rs78271556      125143333.0
#                   rs78772671      125143333.0
# ...                                       ...
# ZXDC              rs7620198       126475919.0
#                   rs77826798      126475919.0
#                   rs78007488      126475919.0
#                   rs9864330       126475919.0
#                   rs999468        126475919.0
#
# [25640 rows x 25 columns]

# %%
mQTL_overlapping_eQTL_idxmin = mQTL_overlapping_eQTL.reset_index(drop=True)

# %%
mQTL_overlapping_eQTL_idxmin = mQTL_overlapping_eQTL_idxmin.loc[
    mQTL_overlapping_eQTL_idxmin.groupby(['snpid','geneSymbol']).pvalue_x.idxmin()].reset_index(drop=True)

# %%
mQTL_overlapping_eQTL_idxmin
# Out:
#              snps                                        gene  statistic_x  \
# 0      rs10002677                               MARCH1;ANP32C    -4.206334
# 1      rs10002697                               MARCH1;ANP32C    -4.206334
# 2      rs10005414                               NOP14;C4orf10     4.177991
# 3      rs10006034                               MARCH1;ANP32C    -4.206334
# 4      rs10007144                                       NPY5R    -4.776194
# ...           ...                                         ...          ...
# 24033   rs9992306  NFXL1;NFXL1;NFXL1;NFXL1;NFXL1;LOC101927157    -4.233884
# 24034   rs9994011                               MARCH1;ANP32C    -4.172229
# 24035    rs999468                                        ZXDC    -4.123829
# 24036    rs999723                           CRLF3;CRLF3;CRLF3    -4.121360
# 24037    rs999724                           CRLF3;CRLF3;CRLF3    -4.121360
#
#        pvalue_x     FDR_x    beta_x  \
# 0      0.000040  0.818639 -0.025389
# 1      0.000040  0.818639 -0.025389
# 2      0.000044  0.826790  0.017688
# 3      0.000040  0.818639 -0.025389
# 4      0.000004  0.588449 -0.009351
# ...         ...       ...       ...
# 24033  0.000035  0.810542 -0.011278
# 24034  0.000045  0.828613 -0.023988
# 24035  0.000055  0.842099 -0.018881
# 24036  0.000056  0.842741 -0.003995
# 24037  0.000056  0.842741 -0.003995
#
#                                            gene_x  chromosome  snpLocation  \
# 0                                   MARCH1;ANP32C           4    165089161
# 1                                   MARCH1;ANP32C           4    165089209
# 2                                   NOP14;C4orf10           4      3755589
# 3                                   MARCH1;ANP32C           4    165090247
# 4                                           NPY5R           4    163795426
# ...                                           ...         ...          ...
# 24033  NFXL1;NFXL1;NFXL1;NFXL1;NFXL1;LOC101927157           4     47403236
# 24034                               MARCH1;ANP32C           4    165090228
# 24035                                        ZXDC           3    127173559
# 24036                           CRLF3;CRLF3;CRLF3          17     29836324
# 24037                           CRLF3;CRLF3;CRLF3          17     29836171
#
#             snpid  ...     FDR_y    beta_y A1  A2    A2freq  \
# 0      rs10002677  ...  0.911105  0.041795  T   C  0.071065
# 1      rs10002697  ...  0.911026  0.041834  T   C  0.071070
# 2      rs10005414  ...  0.987916 -0.004360  C   T  0.340987
# 3      rs10006034  ...  0.911105  0.041795  T   G  0.071075
# 4      rs10007144  ...  0.704918 -0.048108  A   C  0.513884
# ...           ...  ...       ...       ... ..  ..       ...
# 24033   rs9992306  ...  0.853084 -0.050074  T   C  0.099746
# 24034   rs9994011  ...  0.911105  0.041795  C   A  0.071080
# 24035    rs999468  ...  0.818820 -0.043363  C   A  0.184226
# 24036    rs999723  ...  0.962215  0.011547  G   A  0.643915
# 24037    rs999724  ...  0.974297  0.008256  A   C  0.644134
#
#        expressionIncreasingAllele  strand     geneBiotype geneStartPosition  \
# 0                               C    -1.0  protein_coding       163524298.0
# 1                               C    -1.0  protein_coding       163524298.0
# 2                               C    -1.0  protein_coding         2937933.0
# 3                               G    -1.0  protein_coding       163524298.0
# 4                               A     1.0  protein_coding       163343939.0
# ...                           ...     ...             ...               ...
# 24033                           T    -1.0  protein_coding        47847233.0
# 24034                           A    -1.0  protein_coding       163524298.0
# 24035                           C    -1.0  protein_coding       126437601.0
# 24036                           A    -1.0  protein_coding        30769388.0
# 24037                           C    -1.0  protein_coding        30769388.0
#
#        geneEndPosition
# 0          164384050.0
# 1          164384050.0
# 2            2963385.0
# 3          164384050.0
# 4          163351934.0
# ...                ...
# 24033       47914667.0
# 24034      164384050.0
# 24035      126475919.0
# 24036       30824776.0
# 24037       30824776.0
#
# [24038 rows x 25 columns]

# %%
mQTL_overlapping_eQTL_idxmin.to_csv("analysis_using_meta_eQTL/mQTL_overlapping_eQTL.csv", index=False)

# %% [markdown]
# ### Put everything together

# %%
mQTL_overlapping_eQTL_idxmin.columns
# Out:
# Index(['snps', 'gene', 'statistic_x', 'pvalue_x', 'FDR_x', 'beta_x', 'gene_x',
#        'chromosome', 'snpLocation', 'snpid', 'snpLocId', 'gene_y',
#        'geneSymbol', 'statistic_y', 'pvalue_y', 'FDR_y', 'beta_y', 'A1', 'A2',
#        'A2freq', 'expressionIncreasingAllele', 'strand', 'geneBiotype',
#        'geneStartPosition', 'geneEndPosition'],
#       dtype='object')

# %%
pQTL_overlapping_eQTL_idxmin.columns
# Out:
# Index(['CHR', 'POS', 'REF', 'ALT', 'UNIPROT_x', 'BETA', 'SE', 'P', 'FDR_x',
#        'N', 'UNIPROT_y', 'geneSymbol_x', 'chromosome', 'snpLocation', 'snpid',
#        'snpLocId', 'gene', 'geneSymbol_y', 'statistic', 'pvalue', 'FDR_y',
#        'beta', 'A1', 'A2', 'A2freq', 'expressionIncreasingAllele', 'strand',
#        'geneBiotype', 'geneStartPosition', 'geneEndPosition',
#        'statistic_prot'],
#       dtype='object')

# %%
metabQTL_overlapping_eQTL_idxmin.columns
# Out:
# Index(['snps', 'statistic_x', 'pvalue_x', 'FDR_x', 'beta_x', 'ADNI_ID',
#        'chromosome', 'snpLocation', 'snpid', 'snpLocId', 'geneSymbol',
#        'statistic_y', 'pvalue_y', 'FDR_y', 'beta_y', 'A1', 'A2', 'A2freq',
#        'expressionIncreasingAllele', 'strand', 'geneBiotype',
#        'geneStartPosition', 'geneEndPosition'],
#       dtype='object')

# %% [markdown]
# We will use mQTL data frame as a start, use `snpid` and `geneSymbol` as the index, collect `pvalue`, `stat`, `beta` columns, and merge them into one data frame. Then we add GWAS information.

# %%
xQTLs = mQTL_overlapping_eQTL_idxmin.drop(
    columns=['snps', 'gene', 'FDR_x', 'gene_x', 'FDR_y']).rename(
    {'statistic_x':'statistic_methyl', 'pvalue_x':'pvalue_methyl', 'beta_x':'beta_methyl', 'gene_y':'gene', 
       'statistic_y':'statistic_expr', 'pvalue_y':'pvalue_expr', 'beta_y':'beta_expr'}, axis=1)

# %%
xQTLs.columns
# Out:
# Index(['statistic_methyl', 'pvalue_methyl', 'beta_methyl', 'chromosome',
#        'snpLocation', 'snpid', 'snpLocId', 'gene', 'geneSymbol',
#        'statistic_expr', 'pvalue_expr', 'beta_expr', 'A1', 'A2', 'A2freq',
#        'expressionIncreasingAllele', 'strand', 'geneBiotype',
#        'geneStartPosition', 'geneEndPosition'],
#       dtype='object')

# %%
xQTLs.set_index(['geneSymbol', 'snpid'], drop=False, inplace=True)

# %%
pQTL_overlapping_eQTL_idxmin['statistic_prot'] = pQTL_overlapping_eQTL_idxmin['BETA'] / pQTL_overlapping_eQTL_idxmin['SE']

# %%
pQTL_formatted = pQTL_overlapping_eQTL_idxmin[['statistic_prot', 'P', 'BETA', 'snpid', 'geneSymbol_x']].rename(
    {'BETA':'beta_prot', 'P':'pvalue_prot', 'geneSymbol_x':'geneSymbol'}, axis=1)

# %%
pQTL_formatted.set_index(['geneSymbol', 'snpid'], inplace=True)

# %%
xQTLs_prot = pQTL_overlapping_eQTL_idxmin.drop(
    columns=['CHR', 'POS', 'REF', 'ALT', 'UNIPROT_x', 'SE', 'FDR_x', 'N', 'UNIPROT_y', 'geneSymbol_y', 'FDR_y']).rename(
    {'BETA':'beta_prot', 'P':'pvalue_prot', 'geneSymbol_x':'geneSymbol',
     'statistic':'statistic_expr', 'pvalue':'pvalue_expr', 'beta':'beta_expr'}, axis=1)

# %%
xQTLs_prot.columns
# Out:
# Index(['beta_prot', 'pvalue_prot', 'geneSymbol', 'chromosome', 'snpLocation',
#        'snpid', 'snpLocId', 'gene', 'statistic_expr', 'pvalue_expr',
#        'beta_expr', 'A1', 'A2', 'A2freq', 'expressionIncreasingAllele',
#        'strand', 'geneBiotype', 'geneStartPosition', 'geneEndPosition',
#        'statistic_prot'],
#       dtype='object')

# %%
metabQTL_formatted = metabQTL_overlapping_eQTL_idxmin[['statistic_x', 'pvalue_x', 'beta_x', 'snpid', 'geneSymbol']].rename(
    {'statistic_x':'statistic_metab', 'pvalue_x':'pvalue_metab', 'beta_x':'beta_metab'}, axis=1)

# %%
metabQTL_formatted.set_index(['geneSymbol', 'snpid'], inplace=True)

# %%
pQTL_formatted
# Out:
#                       statistic_prot  pvalue_prot  beta_prot
# geneSymbol snpid
# NOC2L      rs2980300        2.263495     0.024436   0.029488
#            rs4970383       -0.078362     0.937601  -0.000840
#            rs4475691       -0.021986     0.982476  -0.000272
# ISG15      rs1806509       -1.087520     0.277683  -0.030620
# NOC2L      rs1806509        1.445340     0.149576   0.013592
# ...                              ...          ...        ...
# SHANK3     rs3810648       -0.974206     0.330724  -0.010342
# RABL2B     rs2285395       -0.010566     0.991581  -0.000572
# SHANK3     rs2285395       -0.861260     0.389769  -0.009642
# RABL2B     rs3865766        1.599020     0.111460   0.041947
# SHANK3     rs3865766       -1.729126     0.084795  -0.009241
#
# [730523 rows x 3 columns]

# %%
metabQTL_formatted
# Out:
#                        statistics_metab  pvalue_metab  beta_metab
# geneSymbol snpid
# AASDH      rs10000003          2.179230      0.030750    2.626286
# PAICS      rs10000003          1.329355      0.185588    0.777456
# POLR2B     rs10000003          1.329355      0.185588    0.777456
# PPAT       rs10000003          2.179230      0.030750    2.626286
# CDS1       rs10000005         -2.383190      0.018314   -2.262149
# ...                                 ...           ...         ...
# ADH5       rs9999976           2.321265      0.021511    4.875438
# EIF4E      rs9999976          -2.565780      0.011195   -3.551833
# SETD7      rs9999981           2.779724      0.006081   12.374678
# ACSL1      rs9999995          -0.942792      0.347182   -0.005681
# ENPP6      rs9999995          -1.202861      0.230774   -0.204481
#
# [2925859 rows x 3 columns]

# %%
xQTLs.index.intersection(pQTL_formatted.index)
# Out:
# MultiIndex([(  'USP20', 'rs10119739'),
#             ( 'COL4A1', 'rs10161783'),
#             ( 'COL4A2', 'rs10161783'),
#             ('JAKMIP1', 'rs10433662'),
#             (  'RMDN2', 'rs10490621'),
#             ( 'CTNNA2', 'rs10496231'),
#             (  'APBB1',  'rs1050239'),
#             (    'HPX',  'rs1050239'),
#             (  'TRIM3',  'rs1050239'),
#             ( 'CAMK1D', 'rs10508449'),
#             ...
#             (  'TUBG1',   'rs938671'),
#             (  'MYH10',   'rs960206'),
#             (   'SPEN',  'rs9633365'),
#             ( 'SUCLG1',   'rs969647'),
#             ( 'PLSCR4',  'rs9838866'),
#             ( 'PLSCR4',  'rs9863647'),
#             (   'ERC2',  'rs9873381'),
#             ( 'CUEDC1',  'rs9893497'),
#             ( 'DNAJC7',  'rs9911974'),
#             ('NKIRAS2',  'rs9911974')],
#            names=['geneSymbol', 'snpid'], length=285)

# %%
xQTLs.index.intersection(metabQTL_formatted.index)
# Out:
# MultiIndex([(   'PFAS',  'rs1001958'),
#             ( 'POLR2A',  'rs1001958'),
#             (  'HMOX2',  'rs1005345'),
#             ( 'DNMT3B',  'rs1007123'),
#             ( 'DNMT3B',  'rs1007124'),
#             (    'GLS', 'rs10176621'),
#             (  'HIBCH', 'rs10176621'),
#             (    'GLS', 'rs10176649'),
#             (  'HIBCH', 'rs10176649'),
#             ( 'NT5C3A', 'rs10224734'),
#             ...
#             (   'NME2',  'rs9896780'),
#             (  'COX10',  'rs9905722'),
#             (  'MLST8',  'rs9921808'),
#             (  'HMOX2',  'rs9930342'),
#             (  'MLST8',  'rs9933986'),
#             (  'ABCC3',   'rs994469'),
#             ('B4GALT6',  'rs9944721'),
#             ('B4GALT6',  'rs9948669'),
#             ( 'ABCB10',  'rs9970564'),
#             ( 'DNMT3B',   'rs998382')],
#            names=['geneSymbol', 'snpid'], length=1264)

# %% [markdown]
# #### add GWAS summary statistic to xQTL

# %%
GWAS.columns
# Out:
# Index(['snps', 'pvalue', 'chr', 'BP', 'effect_allele', 'other_allele',
#        'effect_allele_frequency', 'beta', 'SE', 'SNP_ID', 'GWAS_BETA',
#        'GWAS_SE', 'GWAS_P', 'GWAX_UKBB_BETA', 'GWAX_UKBB_SE', 'GWAX_UKBB_P',
#        'DIRECT', 'I2', 'HET_P', 'INFO', 'statistic_GWAS'],
#       dtype='object')

# %%
GWAS['statistic_GWAS'] = GWAS['beta'] / GWAS['SE']

# %%
GWAS_formatted = GWAS[['statistic_GWAS', 'pvalue', 'beta', 'SNP_ID']].rename(
    {'pvalue':'pvalue_GWAS', 'beta':'beta_GWAS', 'SNP_ID':'snpid'}, axis=1)

# %%
GWAS_formatted
# Out:
#           statistic_GWAS  pvalue_GWAS  beta_GWAS        snpid
# 0               0.624550     0.532266   0.012680   rs61769339
# 1              -0.163141     0.870407  -0.006036  rs190214723
# 2               0.208924     0.834508   0.003903   rs12238997
# 3              -1.442129     0.149266  -0.039365   rs72631875
# 4              -1.255844     0.209173  -0.064142  rs181440659
# ...                  ...          ...        ...          ...
# 10687072       -0.768985     0.441902  -0.015827    rs9616985
# 10687073        0.321851     0.747566   0.005819  rs144549712
# 10687074        0.686054     0.492679   0.008820    rs9616839
# 10687075       -1.661472     0.096619  -0.023551  rs200507571
# 10687076        0.463159     0.643251   0.005887    rs3896457
#
# [10687077 rows x 4 columns]

# %%
xQTLs = xQTLs.reset_index(drop=True).merge(GWAS_formatted, on = 'snpid', how = 'left')

# %%
xQTLs
# Out:
#        statistic_methyl  pvalue_methyl  beta_methyl  chromosome  snpLocation  \
# 0             -4.206334       0.000040    -0.025389           4    165089161
# 1             -4.206334       0.000040    -0.025389           4    165089209
# 2              4.177991       0.000044     0.017688           4      3755589
# 3             -4.206334       0.000040    -0.025389           4    165090247
# 4             -4.776194       0.000004    -0.009351           4    163795426
# ...                 ...            ...          ...         ...          ...
# 24033         -4.233884       0.000035    -0.011278           4     47403236
# 24034         -4.172229       0.000045    -0.023988           4    165090228
# 24035         -4.123829       0.000055    -0.018881           3    127173559
# 24036         -4.121360       0.000056    -0.003995          17     29836324
# 24037         -4.121360       0.000056    -0.003995          17     29836171
#
#             snpid         snpLocId             gene geneSymbol  \
# 0      rs10002677  4:165089161_T_C  ENSG00000145416     MARCH1
# 1      rs10002697  4:165089209_T_C  ENSG00000145416     MARCH1
# 2      rs10005414    4:3755589_C_T  ENSG00000087269      NOP14
# 3      rs10006034  4:165090247_T_G  ENSG00000145416     MARCH1
# 4      rs10007144  4:163795426_A_C  ENSG00000164129      NPY5R
# ...           ...              ...              ...        ...
# 24033   rs9992306   4:47403236_T_C  ENSG00000170448      NFXL1
# 24034   rs9994011  4:165090228_C_A  ENSG00000145416     MARCH1
# 24035    rs999468  3:127173559_C_A  ENSG00000070476       ZXDC
# 24036    rs999723  17:29836324_G_A  ENSG00000176390      CRLF3
# 24037    rs999724  17:29836171_A_C  ENSG00000176390      CRLF3
#
#        statistic_expr  ...  A2    A2freq expressionIncreasingAllele strand  \
# 0            0.574238  ...   C  0.071065                          C   -1.0
# 1            0.574779  ...   C  0.071070                          C   -1.0
# 2           -0.105813  ...   T  0.340987                          C   -1.0
# 3            0.574240  ...   G  0.071075                          G   -1.0
# 4           -1.267741  ...   C  0.513884                          A    1.0
# ...               ...  ...  ..       ...                        ...    ...
# 24033       -0.814665  ...   C  0.099746                          T   -1.0
# 24034        0.574237  ...   A  0.071080                          A   -1.0
# 24035       -0.912964  ...   A  0.184226                          C   -1.0
# 24036        0.293276  ...   A  0.643915                          A   -1.0
# 24037        0.209403  ...   C  0.644134                          C   -1.0
#
#           geneBiotype geneStartPosition  geneEndPosition statistic_GWAS  \
# 0      protein_coding       163524298.0      164384050.0      -0.410766
# 1      protein_coding       163524298.0      164384050.0      -0.405764
# 2      protein_coding         2937933.0        2963385.0      -0.247638
# 3      protein_coding       163524298.0      164384050.0      -0.422018
# 4      protein_coding       163343939.0      163351934.0      -1.360252
# ...               ...               ...              ...            ...
# 24033  protein_coding        47847233.0       47914667.0       1.093150
# 24034  protein_coding       163524298.0      164384050.0       0.030237
# 24035  protein_coding       126437601.0      126475919.0       0.404713
# 24036  protein_coding        30769388.0       30824776.0      -1.383767
# 24037  protein_coding        30769388.0       30824776.0       1.449465
#
#        pvalue_GWAS  beta_GWAS
# 0         0.681244  -0.007669
# 1         0.684916  -0.007576
# 2         0.804415  -0.002647
# 3         0.673012  -0.007879
# 4         0.173750  -0.012887
# ...            ...        ...
# 24033     0.274328   0.017488
# 24034     0.975878   0.000561
# 24035     0.685688   0.004863
# 24036     0.166430  -0.013639
# 24037     0.147208   0.014328
#
# [24038 rows x 23 columns]

# %%
xQTLs.set_index(['geneSymbol', 'snpid'], drop=False, inplace=True)

# %%
xQTLs_prot = xQTLs_prot.reset_index(drop=True).merge(GWAS_formatted, on = 'snpid', how = 'left')

# %%
xQTLs_prot
# Out:
#         beta_prot  pvalue_prot geneSymbol  chromosome  snpLocation      snpid  \
# 0        0.029488     0.024436      NOC2L           1       785989  rs2980300
# 1       -0.000840     0.937601      NOC2L           1       838555  rs4970383
# 2       -0.000272     0.982476      NOC2L           1       846808  rs4475691
# 3       -0.030620     0.277683      ISG15           1       853954  rs1806509
# 4        0.013592     0.149576      NOC2L           1       853954  rs1806509
# ...           ...          ...        ...         ...          ...        ...
# 730518  -0.010342     0.330724     SHANK3          22     51175626  rs3810648
# 730519  -0.000572     0.991581     RABL2B          22     51178090  rs2285395
# 730520  -0.009642     0.389769     SHANK3          22     51178090  rs2285395
# 730521   0.041947     0.111460     RABL2B          22     51186228  rs3865766
# 730522  -0.009241     0.084795     SHANK3          22     51186228  rs3865766
#
#                snpLocId             gene  statistic_expr   pvalue_expr  ...  \
# 0          1:785989_T_C  ENSG00000188976       -1.011814  3.116270e-01  ...
# 1          1:838555_C_A  ENSG00000188976       -0.371254  7.104481e-01  ...
# 2          1:846808_C_T  ENSG00000188976        1.301034  1.932469e-01  ...
# 3          1:853954_C_A  ENSG00000187608        2.833641  4.602094e-03  ...
# 4          1:853954_C_A  ENSG00000188976       -2.369994  1.778839e-02  ...
# ...                 ...              ...             ...           ...  ...
# 730518  22:51175626_A_G  ENSG00000251322        0.093193  9.257500e-01  ...
# 730519  22:51178090_G_A  ENSG00000079974       10.901612  1.132329e-27  ...
# 730520  22:51178090_G_A  ENSG00000251322        0.233557  8.153286e-01  ...
# 730521  22:51186228_C_T  ENSG00000079974        2.521462  1.168683e-02  ...
# 730522  22:51186228_C_T  ENSG00000251322       -1.539068  1.237878e-01  ...
#
#           A2freq expressionIncreasingAllele strand     geneBiotype  \
# 0       0.836686                          T   -1.0  protein_coding
# 1       0.267010                          C   -1.0  protein_coding
# 2       0.204360                          T   -1.0  protein_coding
# 3       0.578350                          A    1.0  protein_coding
# 4       0.578350                          C   -1.0  protein_coding
# ...          ...                        ...    ...             ...
# 730518  0.068315                          G    1.0  protein_coding
# 730519  0.060391                          A   -1.0  protein_coding
# 730520  0.060391                          A    1.0  protein_coding
# 730521  0.450743                          T   -1.0  protein_coding
# 730522  0.450743                          C    1.0  protein_coding
#
#        geneStartPosition  geneEndPosition statistic_prot  statistic_GWAS  \
# 0               944204.0         959309.0       2.263495        1.143132
# 1               944204.0         959309.0      -0.078362        0.709779
# 2               944204.0         959309.0      -0.021986        0.303449
# 3              1001138.0        1014541.0      -1.087520       -0.322354
# 4               944204.0         959309.0       1.445340       -0.322354
# ...                  ...              ...            ...             ...
# 730518        50674415.0       50733298.0      -0.974206        0.118489
# 730519        50767501.0       50783663.0      -0.010566       -0.367780
# 730520        50674415.0       50733298.0      -0.861260       -0.367780
# 730521        50767501.0       50783663.0       1.599020        0.852352
# 730522        50674415.0       50733298.0      -1.729126        0.852352
#
#         pvalue_GWAS  beta_GWAS
# 0          0.252984   0.018185
# 1          0.477841   0.009305
# 2          0.761548   0.004117
# 3          0.747185  -0.003690
# 4          0.747185  -0.003690
# ...             ...        ...
# 730518     0.905680   0.002345
# 730519     0.713037  -0.007806
# 730520     0.713037  -0.007806
# 730521     0.394019   0.009133
# 730522     0.394019   0.009133
#
# [730523 rows x 23 columns]

# %%
xQTLs_prot.set_index(['geneSymbol', 'snpid'], drop=False, inplace=True)

# %% [markdown]
# #### generate files for xQTLs

# %%
xQTLs_expr_methyl_metab = xQTLs.join(metabQTL_formatted, how = 'inner')

# %%
xQTLs_expr_methyl_metab
# Out:
#                       statistic_methyl  pvalue_methyl  beta_methyl  \
# geneSymbol snpid
# PFAS       rs1001958         -3.981757       0.000097    -0.003156
# POLR2A     rs1001958         -4.004933       0.000088    -0.002794
# HMOX2      rs1005345         -4.137063       0.000052    -0.003982
# DNMT3B     rs1007123          4.079764       0.000066     0.004115
#            rs1007124          4.079764       0.000066     0.004115
# ...                                ...            ...          ...
# ABCC3      rs994469           4.495444       0.000012     0.012815
# B4GALT6    rs9944721          5.051007       0.000001     0.014299
#            rs9948669          5.051007       0.000001     0.014299
# ABCB10     rs9970564         -4.100027       0.000061    -0.013120
# DNMT3B     rs998382           4.033897       0.000079     0.004072
#
#                       chromosome  snpLocation      snpid         snpLocId  \
# geneSymbol snpid
# PFAS       rs1001958          17      7998809  rs1001958   17:7998809_G_A
# POLR2A     rs1001958          17      7998809  rs1001958   17:7998809_G_A
# HMOX2      rs1005345          16      5071284  rs1005345   16:5071284_G_A
# DNMT3B     rs1007123          20     31345840  rs1007123  20:31345840_G_A
#            rs1007124          20     31345752  rs1007124  20:31345752_G_C
# ...                          ...          ...        ...              ...
# ABCC3      rs994469           17     49751383   rs994469  17:49751383_G_A
# B4GALT6    rs9944721          18     30248753  rs9944721  18:30248753_T_C
#            rs9948669          18     30246217  rs9948669  18:30246217_G_A
# ABCB10     rs9970564           1    228854703  rs9970564  1:228854703_A_C
# DNMT3B     rs998382           20     31384136   rs998382  20:31384136_A_G
#
#                                  gene geneSymbol  statistic_expr  ...  strand  \
# geneSymbol snpid                                                  ...
# PFAS       rs1001958  ENSG00000178921       PFAS        0.128417  ...     1.0
# POLR2A     rs1001958  ENSG00000181222     POLR2A       -0.763430  ...     1.0
# HMOX2      rs1005345  ENSG00000103415      HMOX2       -0.735617  ...     1.0
# DNMT3B     rs1007123  ENSG00000088305     DNMT3B       11.374587  ...     1.0
#            rs1007124  ENSG00000088305     DNMT3B       11.348318  ...     1.0
# ...                               ...        ...             ...  ...     ...
# ABCC3      rs994469   ENSG00000108846      ABCC3        0.351243  ...     1.0
# B4GALT6    rs9944721  ENSG00000118276    B4GALT6        0.152788  ...    -1.0
#            rs9948669  ENSG00000118276    B4GALT6        0.153225  ...    -1.0
# ABCB10     rs9970564  ENSG00000135776     ABCB10        1.192923  ...    -1.0
# DNMT3B     rs998382   ENSG00000088305     DNMT3B       10.919790  ...     1.0
#
#                          geneBiotype geneStartPosition geneEndPosition  \
# geneSymbol snpid
# PFAS       rs1001958  protein_coding         8247618.0       8270491.0
# POLR2A     rs1001958  protein_coding         7484366.0       7514616.0
# HMOX2      rs1005345  protein_coding         4474690.0       4510347.0
# DNMT3B     rs1007123  protein_coding        32762385.0      32809356.0
#            rs1007124  protein_coding        32762385.0      32809356.0
# ...                              ...               ...             ...
# ABCC3      rs994469   protein_coding        50634777.0      50692252.0
# B4GALT6    rs9944721  protein_coding        31622247.0      31685836.0
#            rs9948669  protein_coding        31622247.0      31685836.0
# ABCB10     rs9970564  protein_coding       229516582.0     229558695.0
# DNMT3B     rs998382   protein_coding        32762385.0      32809356.0
#
#                       statistic_GWAS pvalue_GWAS  beta_GWAS statistics_metab  \
# geneSymbol snpid
# PFAS       rs1001958       -1.190558    0.233827  -0.012508         2.506006
# POLR2A     rs1001958       -1.190558    0.233827  -0.012508         2.506006
# HMOX2      rs1005345        0.805447    0.420561   0.009750        -1.327270
# DNMT3B     rs1007123       -1.487540    0.136872  -0.014430        -2.261264
#            rs1007124       -1.500543    0.133474  -0.014557        -2.261264
# ...                              ...         ...        ...              ...
# ABCC3      rs994469         0.601550    0.547474   0.009508        -2.283497
# B4GALT6    rs9944721        0.486996    0.626261   0.005584        -1.458831
#            rs9948669       -0.426808    0.669519  -0.004897        -1.458831
# ABCB10     rs9970564       -1.043692    0.296628  -0.017854         1.634609
# DNMT3B     rs998382         1.593665    0.111011   0.015467        -2.048293
#
#                       pvalue_metab  beta_metab
# geneSymbol snpid
# PFAS       rs1001958      0.013191    7.944735
# POLR2A     rs1001958      0.013191    7.944735
# HMOX2      rs1005345      0.186276  -12.562561
# DNMT3B     rs1007123      0.025065  -11.769479
#            rs1007124      0.025065  -11.769479
# ...                            ...         ...
# ABCC3      rs994469       0.023692  -53.403566
# B4GALT6    rs9944721      0.146536   -0.915852
#            rs9948669      0.146536   -0.915852
# ABCB10     rs9970564      0.104061    0.121443
# DNMT3B     rs998382       0.042135   -3.112161
#
# [1264 rows x 26 columns]

# %%
xQTLs_expr_methyl_metab.to_csv("analysis_using_meta_eQTL/xQTLs_expr_methyl_metab.csv", index=False)

# %%
xQTLs_expr_methyl_metab_prot = xQTLs_expr_methyl_metab.join(pQTL_formatted, how = 'inner')

# %%
xQTLs_expr_methyl_metab_prot
# Out:
#                        statistic_methyl  pvalue_methyl  beta_methyl  \
# geneSymbol snpid
# CHKA       rs105147           -3.975225       0.000099    -0.007487
# PLCB4      rs11697318          4.123416       0.000055     0.010511
# CAMK2D     rs11724156          4.076895       0.000067     0.011657
# PLCB4      rs13044386          4.123416       0.000055     0.010511
# ACAA1      rs1384006           4.217958       0.000038     0.004121
# PDE8B      rs251419           -4.042899       0.000076    -0.008941
#            rs251421           -4.042899       0.000076    -0.008941
#            rs251425           -3.983895       0.000096    -0.008817
#            rs251427           -3.983895       0.000096    -0.008817
# GPD1L      rs4078487          -3.977665       0.000098    -0.010320
#            rs4955138          -4.514589       0.000011    -0.008910
# PLCB4      rs7266736           4.123416       0.000055     0.010511
#            rs8115948           4.119838       0.000056     0.010531
#
#                        chromosome  snpLocation       snpid         snpLocId  \
# geneSymbol snpid
# CHKA       rs105147            11     67793014    rs105147  11:67793014_T_C
# PLCB4      rs11697318          20      9132036  rs11697318   20:9132036_A_G
# CAMK2D     rs11724156           4    114478482  rs11724156  4:114478482_T_C
# PLCB4      rs13044386          20      9116155  rs13044386   20:9116155_G_A
# ACAA1      rs1384006            3     38261037   rs1384006   3:38261037_G_A
# PDE8B      rs251419             5     76572671    rs251419   5:76572671_T_G
#            rs251421             5     76572970    rs251421   5:76572970_A_G
#            rs251425             5     76575548    rs251425   5:76575548_G_A
#            rs251427             5     76576396    rs251427   5:76576396_T_G
# GPD1L      rs4078487            3     32245255   rs4078487   3:32245255_C_A
#            rs4955138            3     32248962   rs4955138   3:32248962_G_A
# PLCB4      rs7266736           20      9103343   rs7266736   20:9103343_A_G
#            rs8115948           20      9075391   rs8115948   20:9075391_G_A
#
#                                   gene geneSymbol  statistic_expr  ...  \
# geneSymbol snpid                                                   ...
# CHKA       rs105147    ENSG00000110721       CHKA       -0.105720  ...
# PLCB4      rs11697318  ENSG00000101333      PLCB4        0.068880  ...
# CAMK2D     rs11724156  ENSG00000145349     CAMK2D       -1.262335  ...
# PLCB4      rs13044386  ENSG00000101333      PLCB4        0.137961  ...
# ACAA1      rs1384006   ENSG00000060971      ACAA1       -2.160702  ...
# PDE8B      rs251419    ENSG00000113231      PDE8B       -2.666045  ...
#            rs251421    ENSG00000113231      PDE8B       -2.721243  ...
#            rs251425    ENSG00000113231      PDE8B       -2.711736  ...
#            rs251427    ENSG00000113231      PDE8B       -2.482978  ...
# GPD1L      rs4078487   ENSG00000152642      GPD1L        0.798511  ...
#            rs4955138   ENSG00000152642      GPD1L        0.027756  ...
# PLCB4      rs7266736   ENSG00000101333      PLCB4        0.260663  ...
#            rs8115948   ENSG00000101333      PLCB4        0.794262  ...
#
#                        geneEndPosition  statistic_GWAS pvalue_GWAS beta_GWAS  \
# geneSymbol snpid
# CHKA       rs105147         68121444.0       -0.939465    0.347492 -0.009042
# PLCB4      rs11697318        9481242.0       -1.928319    0.053815 -0.024873
# CAMK2D     rs11724156      113761927.0        1.547257    0.121801  0.017211
# PLCB4      rs13044386        9481242.0        1.880562    0.060032  0.023036
# ACAA1      rs1384006        38137242.0        0.611855    0.540634  0.005834
# PDE8B      rs251419         77429807.0       -0.451519    0.651615 -0.005050
#            rs251421         77429807.0       -0.460147    0.645411 -0.005134
#            rs251425         77429807.0        0.449987    0.652720  0.005028
#            rs251427         77429807.0       -0.503056    0.614925 -0.005618
# GPD1L      rs4078487        32168713.0        1.655144    0.097895  0.025642
#            rs4955138        32168713.0       -1.523021    0.127754 -0.018772
# PLCB4      rs7266736         9481242.0       -1.768636    0.076955 -0.021667
#            rs8115948         9481242.0        2.397550    0.016505  0.030959
#
#                        statistics_metab pvalue_metab  beta_metab  \
# geneSymbol snpid
# CHKA       rs105147            1.215765     0.225832    0.049534
# PLCB4      rs11697318         -1.889990     0.060534  -11.112412
# CAMK2D     rs11724156          1.107513     0.269704    2.333487
# PLCB4      rs13044386         -1.889990     0.060534  -11.112412
# ACAA1      rs1384006           1.528305     0.128375    6.864770
# PDE8B      rs251419           -1.700080     0.091023   -0.125062
#            rs251421           -1.700080     0.091023   -0.125062
#            rs251425           -1.700080     0.091023   -0.125062
#            rs251427           -1.700080     0.091023   -0.125062
# GPD1L      rs4078487           2.383818     0.018284   12.304887
#            rs4955138           1.225679     0.222087    5.182513
# PLCB4      rs7266736          -1.889990     0.060534  -11.112412
#            rs8115948          -2.234379     0.026818  -13.185378
#
#                       statistic_prot  pvalue_prot  beta_prot
# geneSymbol snpid
# CHKA       rs105147        -0.281282     0.778726  -0.003666
# PLCB4      rs11697318       0.186505     0.852172   0.001548
# CAMK2D     rs11724156      -1.011263     0.312690  -0.006693
# PLCB4      rs13044386       0.159889     0.873074   0.001329
# ACAA1      rs1384006       -1.709794     0.088318  -0.013714
# PDE8B      rs251419         0.407349     0.684050   0.003770
#            rs251421         0.407349     0.684050   0.003770
#            rs251425         0.296682     0.766921   0.002750
#            rs251427         0.296682     0.766921   0.002750
# GPD1L      rs4078487       -0.085245     0.932123  -0.000977
#            rs4955138        0.394393     0.693566   0.003305
# PLCB4      rs7266736        0.159889     0.873074   0.001329
#            rs8115948       -0.018157     0.985525  -0.000168
#
# [13 rows x 29 columns]

# %%
xQTLs_expr_methyl_metab_prot.to_csv("analysis_using_meta_eQTL/xQTLs_expr_methyl_metab_prot.csv", index=False)

# %%
xQTLs_expr_methyl_prot = xQTLs.join(pQTL_formatted, how = 'inner')

# %%
xQTLs_expr_methyl_prot
# Out:
#                        statistic_methyl  pvalue_methyl  beta_methyl  \
# geneSymbol snpid
# USP20      rs10119739          4.016134       0.000085     0.011001
# COL4A1     rs10161783          4.090714       0.000063     0.023471
# COL4A2     rs10161783          4.090714       0.000063     0.023471
# JAKMIP1    rs10433662         -4.370089       0.000020    -0.011709
# RMDN2      rs10490621         -4.238548       0.000035    -0.014109
# ...                                 ...            ...          ...
# PLSCR4     rs9863647           4.031429       0.000080     0.013837
# ERC2       rs9873381           4.214607       0.000038     0.011314
# CUEDC1     rs9893497          -4.091561       0.000063    -0.008658
# DNAJC7     rs9911974          -4.292643       0.000028    -0.037424
# NKIRAS2    rs9911974          -4.292643       0.000028    -0.037424
#
#                        chromosome  snpLocation       snpid          snpLocId  \
# geneSymbol snpid
# USP20      rs10119739           9    132690613  rs10119739   9:132690613_A_G
# COL4A1     rs10161783          13    111009055  rs10161783  13:111009055_C_T
# COL4A2     rs10161783          13    111009055  rs10161783  13:111009055_C_T
# JAKMIP1    rs10433662           4      5980110  rs10433662     4:5980110_T_C
# RMDN2      rs10490621           2     38336730  rs10490621    2:38336730_C_A
# ...                           ...          ...         ...               ...
# PLSCR4     rs9863647            3    145967173   rs9863647   3:145967173_T_C
# ERC2       rs9873381            3     56489776   rs9873381    3:56489776_G_A
# CUEDC1     rs9893497           17     56002077   rs9893497   17:56002077_A_G
# DNAJC7     rs9911974           17     40199535   rs9911974   17:40199535_T_G
# NKIRAS2    rs9911974           17     40199535   rs9911974   17:40199535_T_G
#
#                                   gene geneSymbol  statistic_expr  ...  \
# geneSymbol snpid                                                   ...
# USP20      rs10119739  ENSG00000136878      USP20       -0.602034  ...
# COL4A1     rs10161783  ENSG00000187498     COL4A1        0.420458  ...
# COL4A2     rs10161783  ENSG00000134871     COL4A2       -0.359141  ...
# JAKMIP1    rs10433662  ENSG00000152969    JAKMIP1       -0.922036  ...
# RMDN2      rs10490621  ENSG00000115841      RMDN2       -1.800133  ...
# ...                                ...        ...             ...  ...
# PLSCR4     rs9863647   ENSG00000114698     PLSCR4        2.522625  ...
# ERC2       rs9873381   ENSG00000187672       ERC2       -0.092490  ...
# CUEDC1     rs9893497   ENSG00000180891     CUEDC1        0.024448  ...
# DNAJC7     rs9911974   ENSG00000168259     DNAJC7       -1.538995  ...
# NKIRAS2    rs9911974   ENSG00000168256    NKIRAS2       -5.983322  ...
#
#                        strand     geneBiotype geneStartPosition  \
# geneSymbol snpid
# USP20      rs10119739     1.0  protein_coding       129834698.0
# COL4A1     rs10161783    -1.0  protein_coding       110148963.0
# COL4A2     rs10161783     1.0  protein_coding       110305812.0
# JAKMIP1    rs10433662    -1.0  protein_coding         6026199.0
# RMDN2      rs10490621     1.0  protein_coding        37923187.0
# ...                       ...             ...               ...
# PLSCR4     rs9863647     -1.0  protein_coding       146192339.0
# ERC2       rs9873381     -1.0  protein_coding        55508308.0
# CUEDC1     rs9893497     -1.0  protein_coding        57861243.0
# DNAJC7     rs9911974     -1.0  protein_coding        41976433.0
# NKIRAS2    rs9911974      1.0  protein_coding        42011382.0
#
#                       geneEndPosition  statistic_GWAS pvalue_GWAS  beta_GWAS  \
# geneSymbol snpid
# USP20      rs10119739     129881838.0        1.435506    0.151143   0.018719
# COL4A1     rs10161783     110307149.0       -2.333160    0.019640  -0.032043
# COL4A2     rs10161783     110513027.0       -2.333160    0.019640  -0.032043
# JAKMIP1    rs10433662       6200591.0        1.093275    0.274273   0.012774
# RMDN2      rs10490621      38067142.0       -2.680925    0.007342  -0.050149
# ...                               ...             ...         ...        ...
# PLSCR4     rs9863647      146251179.0       -0.536428    0.591663  -0.007354
# ERC2       rs9873381       56468363.0        0.075112    0.940125   0.000735
# CUEDC1     rs9893497       57955323.0        0.168083    0.866518   0.001614
# DNAJC7     rs9911974       42021376.0       -2.348787    0.018835  -0.031045
# NKIRAS2    rs9911974       42025644.0       -2.348787    0.018835  -0.031045
#
#                       statistic_prot  pvalue_prot  beta_prot
# geneSymbol snpid
# USP20      rs10119739       3.404031     0.000754   0.043824
# COL4A1     rs10161783       0.707546     0.479775   0.011586
# COL4A2     rs10161783       0.533788     0.593876   0.007906
# JAKMIP1    rs10433662      -2.095968     0.036906  -0.013818
# RMDN2      rs10490621      -0.977312     0.329187  -0.010999
# ...                              ...          ...        ...
# PLSCR4     rs9863647        3.303193     0.001069   0.062313
# ERC2       rs9873381       -0.711123     0.477549  -0.002640
# CUEDC1     rs9893497       -0.343261     0.731821  -0.005733
# DNAJC7     rs9911974       -1.322625     0.186948  -0.007050
# NKIRAS2    rs9911974        2.193285     0.029796   0.036815
#
# [285 rows x 26 columns]

# %%
xQTLs_expr_methyl_prot.to_csv("analysis_using_meta_eQTL/xQTLs_expr_methyl_prot.csv", index=False)

# %%
xQTLs_expr_methyl_metab_filtered = xQTLs_expr_methyl_metab.loc[xQTLs_expr_methyl_metab.pvalue_expr < 1e-4]

# %%
xQTLs_expr_methyl_metab_filtered
# Out:
#                         statistic_methyl  pvalue_methyl  beta_methyl  \
# geneSymbol snpid
# DNMT3B     rs1007123            4.079764       0.000066     0.004115
#            rs1007124            4.079764       0.000066     0.004115
# ACADS      rs10774565           4.028481       0.000081     0.009894
# ADK        rs11001051          -4.054027       0.000073    -0.007499
# ACADS      rs111409007          4.075141       0.000067     0.010207
# ...                                  ...            ...          ...
# DNMT3B     rs910084             4.075227       0.000067     0.004177
#            rs910085             4.075227       0.000067     0.004177
#            rs927239             4.329370       0.000024     0.004873
# HEMK1      rs9838283           -4.023699       0.000082    -0.010633
# DNMT3B     rs998382             4.033897       0.000079     0.004072
#
#                         chromosome  snpLocation        snpid  \
# geneSymbol snpid
# DNMT3B     rs1007123            20     31345840    rs1007123
#            rs1007124            20     31345752    rs1007124
# ACADS      rs10774565           12    121099149   rs10774565
# ADK        rs11001051           10     76243549   rs11001051
# ACADS      rs111409007          12    121119095  rs111409007
# ...                            ...          ...          ...
# DNMT3B     rs910084             20     31379665     rs910084
#            rs910085             20     31383353     rs910085
#            rs927239             20     31268924     rs927239
# HEMK1      rs9838283             3     50820486    rs9838283
# DNMT3B     rs998382             20     31384136     rs998382
#
#                                 snpLocId             gene geneSymbol  \
# geneSymbol snpid
# DNMT3B     rs1007123     20:31345840_G_A  ENSG00000088305     DNMT3B
#            rs1007124     20:31345752_G_C  ENSG00000088305     DNMT3B
# ACADS      rs10774565   12:121099149_T_C  ENSG00000122971      ACADS
# ADK        rs11001051    10:76243549_C_A  ENSG00000156110        ADK
# ACADS      rs111409007  12:121119095_C_T  ENSG00000122971      ACADS
# ...                                  ...              ...        ...
# DNMT3B     rs910084      20:31379665_C_T  ENSG00000088305     DNMT3B
#            rs910085      20:31383353_T_G  ENSG00000088305     DNMT3B
#            rs927239      20:31268924_G_A  ENSG00000088305     DNMT3B
# HEMK1      rs9838283      3:50820486_G_A  ENSG00000114735      HEMK1
# DNMT3B     rs998382      20:31384136_A_G  ENSG00000088305     DNMT3B
#
#                         statistic_expr  ...  strand     geneBiotype  \
# geneSymbol snpid                        ...
# DNMT3B     rs1007123         11.374587  ...     1.0  protein_coding
#            rs1007124         11.348318  ...     1.0  protein_coding
# ACADS      rs10774565         9.775675  ...     1.0  protein_coding
# ADK        rs11001051        -4.916910  ...     1.0  protein_coding
# ACADS      rs111409007        8.880935  ...     1.0  protein_coding
# ...                                ...  ...     ...             ...
# DNMT3B     rs910084          10.777169  ...     1.0  protein_coding
#            rs910085          10.572637  ...     1.0  protein_coding
#            rs927239          -6.027501  ...     1.0  protein_coding
# HEMK1      rs9838283          9.200060  ...     1.0  protein_coding
# DNMT3B     rs998382          10.919790  ...     1.0  protein_coding
#
#                        geneStartPosition geneEndPosition  statistic_GWAS  \
# geneSymbol snpid
# DNMT3B     rs1007123          32762385.0      32809356.0       -1.487540
#            rs1007124          32762385.0      32809356.0       -1.500543
# ACADS      rs10774565        120725735.0     120740008.0       -1.118446
# ADK        rs11001051         74151185.0      74709303.0        1.507212
# ACADS      rs111409007       120725735.0     120740008.0        0.879022
# ...                                  ...             ...             ...
# DNMT3B     rs910084           32762385.0      32809356.0       -1.666355
#            rs910085           32762385.0      32809356.0        1.609339
#            rs927239           32762385.0      32809356.0        0.615395
# HEMK1      rs9838283          50569152.0      50596168.0        0.500765
# DNMT3B     rs998382           32762385.0      32809356.0        1.593665
#
#                        pvalue_GWAS  beta_GWAS statistics_metab  pvalue_metab  \
# geneSymbol snpid
# DNMT3B     rs1007123      0.136872  -0.014430        -2.261264      0.025065
#            rs1007124      0.133474  -0.014557        -2.261264      0.025065
# ACADS      rs10774565     0.263376  -0.015004        -2.414911      0.016846
# ADK        rs11001051     0.131756   0.016219         1.784702      0.076170
# ACADS      rs111409007    0.379389   0.011735        -3.018829      0.002946
# ...                            ...        ...              ...           ...
# DNMT3B     rs910084       0.095643  -0.016302        -1.817513      0.070975
#            rs910085       0.107542   0.015739        -1.875935      0.062452
#            rs927239       0.538294   0.006062        -1.801808      0.073424
# HEMK1      rs9838283      0.616536   0.007118         3.017857      0.002955
# DNMT3B     rs998382       0.111011   0.015467        -2.048293      0.042135
#
#                         beta_metab
# geneSymbol snpid
# DNMT3B     rs1007123    -11.769479
#            rs1007124    -11.769479
# ACADS      rs10774565    -5.564403
# ADK        rs11001051     0.203476
# ACADS      rs111409007   -7.002376
# ...                            ...
# DNMT3B     rs910084      -2.784711
#            rs910085      -2.878097
#            rs927239     -10.596858
# HEMK1      rs9838283     50.013139
# DNMT3B     rs998382      -3.112161
#
# [65 rows x 26 columns]

# %%
xQTLs_expr_methyl_metab_filtered.to_csv("analysis_using_meta_eQTL/xQTLs_expr_methyl_metab_filtered_1e-4.csv", index=False)

# %%
xQTLs_expr_metab_prot = xQTLs_prot.join(metabQTL_formatted, how = 'inner')

# %%
xQTLs_expr_metab_prot
# Out:
#                       beta_prot  pvalue_prot geneSymbol  chromosome  \
# geneSymbol snpid
# DVL1       rs7528416   0.000419     0.963906       DVL1           1
#            rs6697886   0.000403     0.960245       DVL1           1
#            rs4970364  -0.005612     0.397592       DVL1           1
#            rs6675798  -0.006418     0.474499       DVL1           1
#            rs2297864  -0.006418     0.474499       DVL1           1
# ...                         ...          ...        ...         ...
# ARSA       rs6010061   0.042923     0.000769       ARSA          22
#            rs6010063   0.011650     0.401975       ARSA          22
#            rs10451     0.023319     0.120453       ARSA          22
#            rs715586   -0.006474     0.757270       ARSA          22
#            rs8137951   0.024978     0.095344       ARSA          22
#
#                       snpLocation      snpid         snpLocId  \
# geneSymbol snpid
# DVL1       rs7528416      1171249  rs7528416    1:1171249_T_C
#            rs6697886      1173611  rs6697886    1:1173611_G_A
#            rs4970364      1174282  rs4970364    1:1174282_T_C
#            rs6675798      1176597  rs6675798    1:1176597_T_C
#            rs2297864      1177630  rs2297864    1:1177630_A_G
# ...                           ...        ...              ...
# ARSA       rs6010061     51151724  rs6010061  22:51151724_C_T
#            rs6010063     51156933  rs6010063  22:51156933_A_G
#            rs10451       51162059    rs10451  22:51162059_G_A
#            rs715586      51163138   rs715586  22:51163138_C_T
#            rs8137951     51165664  rs8137951  22:51165664_G_A
#
#                                  gene  statistic_expr   pvalue_expr  ...  \
# geneSymbol snpid                                                     ...
# DVL1       rs7528416  ENSG00000107404        1.338474  1.807421e-01  ...
#            rs6697886  ENSG00000107404        1.940041  5.237470e-02  ...
#            rs4970364  ENSG00000107404       -0.105954  9.156187e-01  ...
#            rs6675798  ENSG00000107404        2.395601  1.659316e-02  ...
#            rs2297864  ENSG00000107404        2.237343  2.526396e-02  ...
# ...                               ...             ...           ...  ...
# ARSA       rs6010061  ENSG00000100299        6.310465  2.781990e-10  ...
#            rs6010063  ENSG00000100299        5.127080  2.942710e-07  ...
#            rs10451    ENSG00000100299        4.196230  2.713946e-05  ...
#            rs715586   ENSG00000100299        0.930321  3.522047e-01  ...
#            rs8137951  ENSG00000100299        4.353607  1.339159e-05  ...
#
#                          geneBiotype geneStartPosition geneEndPosition  \
# geneSymbol snpid
# DVL1       rs7528416  protein_coding         1335276.0       1349350.0
#            rs6697886  protein_coding         1335276.0       1349350.0
#            rs4970364  protein_coding         1335276.0       1349350.0
#            rs6675798  protein_coding         1335276.0       1349350.0
#            rs2297864  protein_coding         1335276.0       1349350.0
# ...                              ...               ...             ...
# ARSA       rs6010061  protein_coding        50622754.0      50628173.0
#            rs6010063  protein_coding        50622754.0      50628173.0
#            rs10451    protein_coding        50622754.0      50628173.0
#            rs715586   protein_coding        50622754.0      50628173.0
#            rs8137951  protein_coding        50622754.0      50628173.0
#
#                       statistic_prot statistic_GWAS  pvalue_GWAS beta_GWAS  \
# geneSymbol snpid
# DVL1       rs7528416        0.045290      -1.994677     0.046078 -0.032855
#            rs6697886        0.049888       0.441435     0.658898  0.006154
#            rs4970364       -0.847144       0.167264     0.867162  0.001886
#            rs6675798       -0.716084       0.240721     0.809771  0.003889
#            rs2297864       -0.716084       0.291528     0.770647  0.004730
# ...                              ...            ...          ...       ...
# ARSA       rs6010061        3.399442      -0.208219     0.835058 -0.002049
#            rs6010063        0.839318      -1.637657     0.101493 -0.015725
#            rs10451          1.557408       0.500160     0.616962  0.005208
#            rs715586        -0.309357       1.978756     0.047843  0.026554
#            rs8137951        1.673256       0.504564     0.613865  0.005228
#
#                       statistics_metab  pvalue_metab  beta_metab
# geneSymbol snpid
# DVL1       rs7528416          0.979838      0.328618    2.975937
#            rs6697886         -0.908323      0.365049   -7.354410
#            rs4970364         -1.305791      0.193464   -8.278414
#            rs6675798         -0.712314      0.477289   -6.761995
#            rs2297864         -0.712314      0.477289   -6.761995
# ...                                ...           ...         ...
# ARSA       rs6010061          2.199838      0.029226    3.765515
#            rs6010063          2.191276      0.029851    0.082448
#            rs10451            1.918129      0.056843   11.259549
#            rs715586           2.571247      0.011027    0.150297
#            rs8137951          2.074059      0.039646   12.160708
#
# [57097 rows x 26 columns]

# %%
xQTLs_expr_metab_prot.columns
# Out:
# Index(['beta_prot', 'pvalue_prot', 'geneSymbol', 'chromosome', 'snpLocation',
#        'snpid', 'snpLocId', 'gene', 'statistic_expr', 'pvalue_expr',
#        'beta_expr', 'A1', 'A2', 'A2freq', 'expressionIncreasingAllele',
#        'strand', 'geneBiotype', 'geneStartPosition', 'geneEndPosition',
#        'statistic_prot', 'statistic_GWAS', 'pvalue_GWAS', 'beta_GWAS',
#        'statistics_metab', 'pvalue_metab', 'beta_metab'],
#       dtype='object')

# %%
xQTLs_expr_metab_prot.to_csv("analysis_using_meta_eQTL/xQTLs_expr_metab_prot.csv", index=False)

# %% [markdown]
# #### add a patch of methylQTL to xQTLs_expr_metab_prot

# %%
xQTLs_expr_metab_prot = pd.read_csv("analysis_using_meta_eQTL/xQTLs_expr_metab_prot.csv")

# %%
xQTLs_expr_metab_prot
# Out:
#        beta_prot  pvalue_prot geneSymbol  chromosome  snpLocation      snpid  \
# 0       0.000419     0.963906       DVL1           1      1171249  rs7528416
# 1       0.000403     0.960245       DVL1           1      1173611  rs6697886
# 2      -0.005612     0.397592       DVL1           1      1174282  rs4970364
# 3      -0.006418     0.474499       DVL1           1      1176597  rs6675798
# 4      -0.006418     0.474499       DVL1           1      1177630  rs2297864
# ...          ...          ...        ...         ...          ...        ...
# 57092   0.042923     0.000769       ARSA          22     51151724  rs6010061
# 57093   0.011650     0.401975       ARSA          22     51156933  rs6010063
# 57094   0.023319     0.120453       ARSA          22     51162059    rs10451
# 57095  -0.006474     0.757270       ARSA          22     51163138   rs715586
# 57096   0.024978     0.095344       ARSA          22     51165664  rs8137951
#
#               snpLocId             gene  statistic_expr   pvalue_expr  ...  \
# 0        1:1171249_T_C  ENSG00000107404        1.338474  1.807421e-01  ...
# 1        1:1173611_G_A  ENSG00000107404        1.940041  5.237470e-02  ...
# 2        1:1174282_T_C  ENSG00000107404       -0.105954  9.156187e-01  ...
# 3        1:1176597_T_C  ENSG00000107404        2.395601  1.659316e-02  ...
# 4        1:1177630_A_G  ENSG00000107404        2.237343  2.526396e-02  ...
# ...                ...              ...             ...           ...  ...
# 57092  22:51151724_C_T  ENSG00000100299        6.310465  2.781990e-10  ...
# 57093  22:51156933_A_G  ENSG00000100299        5.127080  2.942710e-07  ...
# 57094  22:51162059_G_A  ENSG00000100299        4.196230  2.713946e-05  ...
# 57095  22:51163138_C_T  ENSG00000100299        0.930321  3.522047e-01  ...
# 57096  22:51165664_G_A  ENSG00000100299        4.353607  1.339159e-05  ...
#
#           geneBiotype geneStartPosition geneEndPosition  statistic_prot  \
# 0      protein_coding         1335276.0       1349350.0        0.045290
# 1      protein_coding         1335276.0       1349350.0        0.049888
# 2      protein_coding         1335276.0       1349350.0       -0.847144
# 3      protein_coding         1335276.0       1349350.0       -0.716084
# 4      protein_coding         1335276.0       1349350.0       -0.716084
# ...               ...               ...             ...             ...
# 57092  protein_coding        50622754.0      50628173.0        3.399442
# 57093  protein_coding        50622754.0      50628173.0        0.839318
# 57094  protein_coding        50622754.0      50628173.0        1.557408
# 57095  protein_coding        50622754.0      50628173.0       -0.309357
# 57096  protein_coding        50622754.0      50628173.0        1.673256
#
#       statistic_GWAS  pvalue_GWAS beta_GWAS  statistic_metab  pvalue_metab  \
# 0          -1.994677     0.046078 -0.032855         0.979838      0.328618
# 1           0.441435     0.658898  0.006154        -0.908323      0.365049
# 2           0.167264     0.867162  0.001886        -1.305791      0.193464
# 3           0.240721     0.809771  0.003889        -0.712314      0.477289
# 4           0.291528     0.770647  0.004730        -0.712314      0.477289
# ...              ...          ...       ...              ...           ...
# 57092      -0.208219     0.835058 -0.002049         2.199838      0.029226
# 57093      -1.637657     0.101493 -0.015725         2.191276      0.029851
# 57094       0.500160     0.616962  0.005208         1.918129      0.056843
# 57095       1.978756     0.047843  0.026554         2.571247      0.011027
# 57096       0.504564     0.613865  0.005228         2.074059      0.039646
#
#        beta_metab
# 0        2.975937
# 1       -7.354410
# 2       -8.278414
# 3       -6.761995
# 4       -6.761995
# ...           ...
# 57092    3.765515
# 57093    0.082448
# 57094   11.259549
# 57095    0.150297
# 57096   12.160708
#
# [57097 rows x 26 columns]

# %%
mQTL
# Out:
#                 snps                                          gene  statistic  \
# 0          rs2069978                                GPX4;GPX4;GPX4   9.889386
# 1          rs2069978                      GPX4;GPX4;GPX4;GPX4;GPX4   9.607171
# 2          rs2069984                                GPX4;GPX4;GPX4   9.085744
# 3          rs2069987                                GPX4;GPX4;GPX4   9.085744
# 4         rs60428566                                GPX4;GPX4;GPX4   9.085744
# ...              ...                                           ...        ...
# 30888009   rs1355106  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888010   rs1355107  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888011  rs12499737  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888012  rs12504629  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
# 30888013  rs12500602  PDE4DIP;PDE4DIP;PDE4DIP;PDE4DIP;NBPF20;NBPF9  -3.341382
#
#                 pvalue           FDR      beta
# 0         6.223929e-19  1.847805e-08  0.078782
# 1         4.019592e-18  5.966828e-08  0.109791
# 2         1.201035e-16  5.942866e-07  0.070466
# 3         1.201035e-16  5.942866e-07  0.070466
# 4         1.201035e-16  5.942866e-07  0.070466
# ...                ...           ...       ...
# 30888009  1.000000e-03  9.611729e-01 -0.013573
# 30888010  1.000000e-03  9.611729e-01 -0.013573
# 30888011  1.000000e-03  9.611729e-01 -0.013573
# 30888012  1.000000e-03  9.611729e-01 -0.013573
# 30888013  1.000000e-03  9.611729e-01 -0.013573
#
# [30888014 rows x 6 columns]

# %%
gene_group_to_gene
# Out:
#                             gene
# Symbol
# ASIC2                 AA06;ASIC2
# AA06                  AA06;ASIC2
# AACS                        AACS
# AACS                   AACS;AACS
# AACSL                      AACSL
# ...                          ...
# ZPLD1                      ZPLD1
# TUBGCP4          ZSCAN29;TUBGCP4
# ZSCAN29          ZSCAN29;TUBGCP4
# TUBGCP4  ZSCAN29;TUBGCP4;TUBGCP4
# ZSCAN29  ZSCAN29;TUBGCP4;TUBGCP4
#
# [6768 rows x 1 columns]

# %%
xQTLs_expr_metab_prot.geneSymbol
# Out:
# 0        DVL1
# 1        DVL1
# 2        DVL1
# 3        DVL1
# 4        DVL1
#          ...
# 57092    ARSA
# 57093    ARSA
# 57094    ARSA
# 57095    ARSA
# 57096    ARSA
# Name: geneSymbol, Length: 57097, dtype: object

# %%
gene_group_to_gene_filtered = gene_group_to_gene[
    gene_group_to_gene.index.isin(np.unique(xQTLs_expr_metab_prot.geneSymbol))]

# %%
gene_group_to_gene_filtered
# Out:
#                            gene
# Symbol
# ASIC2                AA06;ASIC2
# AACS                       AACS
# AACS                  AACS;AACS
# AADAT               AADAT;AADAT
# AADAT         AADAT;AADAT;AADAT
# ...                         ...
# CSAD    ZNF740;ZNF740;CSAD;CSAD
# PLOD3              ZNHIT1;PLOD3
# PLOD3        ZNHIT1;PLOD3;PLOD3
# PLOD3       ZNHIT1;PLOD3;ZNHIT1
# PLOD3       ZNHIT1;ZNHIT1;PLOD3
#
# [2257 rows x 1 columns]

# %%
xQTLs_expr_metab_prot_with_gene_groups = xQTLs_expr_metab_prot.merge(gene_group_to_gene_filtered,
                                                                     left_on = ['geneSymbol'], 
                                                                     right_on = ['Symbol'],
                                                                     how = 'inner',
                                                                     suffixes=('', '_y'))

# %%
xQTLs_expr_metab_prot_with_gene_groups
# Out:
#         beta_prot  pvalue_prot geneSymbol  chromosome  snpLocation      snpid  \
# 0        0.000419     0.963906       DVL1           1      1171249  rs7528416
# 1        0.000403     0.960245       DVL1           1      1173611  rs6697886
# 2       -0.005612     0.397592       DVL1           1      1174282  rs4970364
# 3       -0.006418     0.474499       DVL1           1      1176597  rs6675798
# 4       -0.006418     0.474499       DVL1           1      1177630  rs2297864
# ...           ...          ...        ...         ...          ...        ...
# 235567  -0.006474     0.757270       ARSA          22     51163138   rs715586
# 235568  -0.006474     0.757270       ARSA          22     51163138   rs715586
# 235569   0.024978     0.095344       ARSA          22     51165664  rs8137951
# 235570   0.024978     0.095344       ARSA          22     51165664  rs8137951
# 235571   0.024978     0.095344       ARSA          22     51165664  rs8137951
#
#                snpLocId             gene  statistic_expr  pvalue_expr  ...  \
# 0         1:1171249_T_C  ENSG00000107404        1.338474     0.180742  ...
# 1         1:1173611_G_A  ENSG00000107404        1.940041     0.052375  ...
# 2         1:1174282_T_C  ENSG00000107404       -0.105954     0.915619  ...
# 3         1:1176597_T_C  ENSG00000107404        2.395601     0.016593  ...
# 4         1:1177630_A_G  ENSG00000107404        2.237343     0.025264  ...
# ...                 ...              ...             ...          ...  ...
# 235567  22:51163138_C_T  ENSG00000100299        0.930321     0.352205  ...
# 235568  22:51163138_C_T  ENSG00000100299        0.930321     0.352205  ...
# 235569  22:51165664_G_A  ENSG00000100299        4.353607     0.000013  ...
# 235570  22:51165664_G_A  ENSG00000100299        4.353607     0.000013  ...
# 235571  22:51165664_G_A  ENSG00000100299        4.353607     0.000013  ...
#
#         geneStartPosition geneEndPosition statistic_prot  statistic_GWAS  \
# 0               1335276.0       1349350.0       0.045290       -1.994677
# 1               1335276.0       1349350.0       0.049888        0.441435
# 2               1335276.0       1349350.0      -0.847144        0.167264
# 3               1335276.0       1349350.0      -0.716084        0.240721
# 4               1335276.0       1349350.0      -0.716084        0.291528
# ...                   ...             ...            ...             ...
# 235567         50622754.0      50628173.0      -0.309357        1.978756
# 235568         50622754.0      50628173.0      -0.309357        1.978756
# 235569         50622754.0      50628173.0       1.673256        0.504564
# 235570         50622754.0      50628173.0       1.673256        0.504564
# 235571         50622754.0      50628173.0       1.673256        0.504564
#
#        pvalue_GWAS  beta_GWAS statistic_metab  pvalue_metab  beta_metab  \
# 0         0.046078  -0.032855        0.979838      0.328618    2.975937
# 1         0.658898   0.006154       -0.908323      0.365049   -7.354410
# 2         0.867162   0.001886       -1.305791      0.193464   -8.278414
# 3         0.809771   0.003889       -0.712314      0.477289   -6.761995
# 4         0.770647   0.004730       -0.712314      0.477289   -6.761995
# ...            ...        ...             ...           ...         ...
# 235567    0.047843   0.026554        2.571247      0.011027    0.150297
# 235568    0.047843   0.026554        2.571247      0.011027    0.150297
# 235569    0.613865   0.005228        2.074059      0.039646   12.160708
# 235570    0.613865   0.005228        2.074059      0.039646   12.160708
# 235571    0.613865   0.005228        2.074059      0.039646   12.160708
#
#                                                    gene_y
# 0                                                    DVL1
# 1                                                    DVL1
# 2                                                    DVL1
# 3                                                    DVL1
# 4                                                    DVL1
# ...                                                   ...
# 235567       ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA
# 235568  ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA
# 235569                           ARSA;ARSA;ARSA;ARSA;ARSA
# 235570       ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA
# 235571  ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA;ARSA
#
# [235572 rows x 27 columns]

# %%
xQTLs_expr_metab_prot_methyl = xQTLs_expr_metab_prot_with_gene_groups.merge(mQTL,
                                             left_on = ['gene_y', 'snpid'], 
                                             right_on = ['gene', 'snps'],
                                             how = 'inner',
                                             suffixes=('', '_mQTL'))

# %%
xQTLs_expr_metab_prot_methyl
# Out:
#      beta_prot   pvalue_prot geneSymbol  chromosome  snpLocation       snpid  \
# 0    -0.054173  1.791532e-02        CDA           1     20884941  rs12134554
# 1    -0.011035  4.910495e-01        CDA           1     20893965    rs472055
# 2    -0.009748  2.573151e-01     PRKAA2           1     57216376   rs6696458
# 3    -0.007009  3.718588e-01     PRKAA2           1     57221878   rs2298127
# 4    -0.007009  3.718588e-01     PRKAA2           1     57231991  rs12410615
# ..         ...           ...        ...         ...          ...         ...
# 302   0.079164  2.429989e-13       GART          21     34821372   rs2834216
# 303   0.133763  4.788447e-30       GART          21     34892163   rs2409495
# 304   0.125477  5.285556e-30       GART          21     34894623   rs2834234
# 305   0.122274  3.252704e-29       GART          21     34986862   rs6517183
# 306  -0.012954  6.096102e-01      ABCG1          21     43684321  rs17767083
#
#             snpLocId             gene  statistic_expr  pvalue_expr  ...  \
# 0     1:20884941_T_C  ENSG00000158825        0.542508     0.587469  ...
# 1     1:20893965_G_A  ENSG00000158825       -2.480295     0.013127  ...
# 2     1:57216376_G_A  ENSG00000162409       -0.245578     0.806009  ...
# 3     1:57221878_A_C  ENSG00000162409       -1.790089     0.073440  ...
# 4     1:57231991_G_A  ENSG00000162409       -1.818491     0.068989  ...
# ..               ...              ...             ...          ...  ...
# 302  21:34821372_A_G  ENSG00000159131        3.346643     0.000818  ...
# 303  21:34892163_A_G  ENSG00000159131        3.298330     0.000973  ...
# 304  21:34894623_T_C  ENSG00000159131        3.600479     0.000318  ...
# 305  21:34986862_G_A  ENSG00000159131        3.935685     0.000083  ...
# 306  21:43684321_C_T  ENSG00000160179       -0.265216     0.790843  ...
#
#      statistic_metab pvalue_metab beta_metab  \
# 0          -2.118558     0.035644 -32.344288
# 1          -2.476995     0.014270 -10.452803
# 2           2.341422     0.020420   0.131697
# 3          -2.102151     0.037077 -37.214072
# 4          -2.102151     0.037077 -37.214072
# ..               ...          ...        ...
# 302         1.735614     0.084522   2.304386
# 303         2.272207     0.024381   3.322802
# 304         1.772149     0.078238   2.620384
# 305        -1.739548     0.083826  -8.396733
# 306        -3.168998     0.001827 -21.926142
#
#                                     gene_y        snps  \
# 0                                      CDA  rs12134554
# 1                                      CDA    rs472055
# 2                                   PRKAA2   rs6696458
# 3                                   PRKAA2   rs2298127
# 4                                   PRKAA2  rs12410615
# ..                                     ...         ...
# 302  SON;GART;SON;GART;GART;GART;GART;GART   rs2834216
# 303  SON;GART;SON;GART;GART;GART;GART;GART   rs2409495
# 304  SON;GART;SON;GART;GART;GART;GART;GART   rs2834234
# 305  SON;GART;SON;GART;GART;GART;GART;GART   rs6517183
# 306          ABCG1;ABCG1;ABCG1;ABCG1;ABCG1  rs17767083
#
#                                  gene_mQTL statistic    pvalue       FDR  \
# 0                                      CDA -3.508221  0.000561  0.944759
# 1                                      CDA  3.968124  0.000102  0.866868
# 2                                   PRKAA2  3.792661  0.000199  0.901952
# 3                                   PRKAA2  3.344187  0.000990  0.960962
# 4                                   PRKAA2  3.344187  0.000990  0.960962
# ..                                     ...       ...       ...       ...
# 302  SON;GART;SON;GART;GART;GART;GART;GART -3.546968  0.000489  0.939947
# 303  SON;GART;SON;GART;GART;GART;GART;GART -3.473863  0.000633  0.948285
# 304  SON;GART;SON;GART;GART;GART;GART;GART -3.375746  0.000889  0.958191
# 305  SON;GART;SON;GART;GART;GART;GART;GART -3.858935  0.000155  0.889446
# 306          ABCG1;ABCG1;ABCG1;ABCG1;ABCG1 -3.449151  0.000690  0.950851
#
#          beta
# 0   -0.017089
# 1    0.013397
# 2    0.014877
# 3    0.011546
# 4    0.011546
# ..        ...
# 302 -0.003990
# 303 -0.004264
# 304 -0.004038
# 305 -0.004245
# 306 -0.013777
#
# [307 rows x 33 columns]

# %%
xQTLs_expr_metab_prot_methyl.columns
# Out:
# Index(['beta_prot', 'pvalue_prot', 'geneSymbol', 'chromosome', 'snpLocation',
#        'snpid', 'snpLocId', 'gene', 'statistic_expr', 'pvalue_expr',
#        'beta_expr', 'A1', 'A2', 'A2freq', 'expressionIncreasingAllele',
#        'strand', 'geneBiotype', 'geneStartPosition', 'geneEndPosition',
#        'statistic_prot', 'statistic_GWAS', 'pvalue_GWAS', 'beta_GWAS',
#        'statistic_metab', 'pvalue_metab', 'beta_metab', 'gene_y', 'snps',
#        'gene_mQTL', 'statistic', 'pvalue', 'FDR', 'beta'],
#       dtype='object')

# %%
xQTLs_expr_metab_prot_methyl = xQTLs_expr_metab_prot_methyl.rename({'statistic': 'statistic_methyl',
                                                                    'pvalue': 'pvalue_methyl',
                                                                    'beta': 'beta_methyl'},
            axis=1).drop(['gene_y', 'snps', 'gene_mQTL', 'FDR'], axis=1)

# %%
xQTLs_expr_metab_prot_methyl
# Out:
#      beta_prot   pvalue_prot geneSymbol  chromosome  snpLocation       snpid  \
# 0    -0.054173  1.791532e-02        CDA           1     20884941  rs12134554
# 1    -0.011035  4.910495e-01        CDA           1     20893965    rs472055
# 2    -0.009748  2.573151e-01     PRKAA2           1     57216376   rs6696458
# 3    -0.007009  3.718588e-01     PRKAA2           1     57221878   rs2298127
# 4    -0.007009  3.718588e-01     PRKAA2           1     57231991  rs12410615
# ..         ...           ...        ...         ...          ...         ...
# 302   0.079164  2.429989e-13       GART          21     34821372   rs2834216
# 303   0.133763  4.788447e-30       GART          21     34892163   rs2409495
# 304   0.125477  5.285556e-30       GART          21     34894623   rs2834234
# 305   0.122274  3.252704e-29       GART          21     34986862   rs6517183
# 306  -0.012954  6.096102e-01      ABCG1          21     43684321  rs17767083
#
#             snpLocId             gene  statistic_expr  pvalue_expr  ...  \
# 0     1:20884941_T_C  ENSG00000158825        0.542508     0.587469  ...
# 1     1:20893965_G_A  ENSG00000158825       -2.480295     0.013127  ...
# 2     1:57216376_G_A  ENSG00000162409       -0.245578     0.806009  ...
# 3     1:57221878_A_C  ENSG00000162409       -1.790089     0.073440  ...
# 4     1:57231991_G_A  ENSG00000162409       -1.818491     0.068989  ...
# ..               ...              ...             ...          ...  ...
# 302  21:34821372_A_G  ENSG00000159131        3.346643     0.000818  ...
# 303  21:34892163_A_G  ENSG00000159131        3.298330     0.000973  ...
# 304  21:34894623_T_C  ENSG00000159131        3.600479     0.000318  ...
# 305  21:34986862_G_A  ENSG00000159131        3.935685     0.000083  ...
# 306  21:43684321_C_T  ENSG00000160179       -0.265216     0.790843  ...
#
#      statistic_prot statistic_GWAS pvalue_GWAS  beta_GWAS statistic_metab  \
# 0         -2.383621       0.949027    0.342607   0.014007       -2.118558
# 1         -0.689691      -1.990737    0.046510  -0.018911       -2.476995
# 2         -1.134877       2.153163    0.031306   0.027700        2.341422
# 3         -0.894310      -1.250113    0.211258  -0.014205       -2.102151
# 4         -0.894310       1.217821    0.223292   0.013833       -2.102151
# ..              ...            ...         ...        ...             ...
# 302        7.662269       1.042058    0.297385   0.010693        1.735614
# 303       12.720786       1.025291    0.305226   0.012303        2.272207
# 304       12.708979       1.173989    0.240400   0.013047        1.772149
# 305       12.491291      -0.946790    0.343746  -0.010173       -1.739548
# 306       -0.511516       0.281922    0.778003   0.004217       -3.168998
#
#      pvalue_metab beta_metab  statistic_methyl  pvalue_methyl  beta_methyl
# 0        0.035644 -32.344288         -3.508221       0.000561    -0.017089
# 1        0.014270 -10.452803          3.968124       0.000102     0.013397
# 2        0.020420   0.131697          3.792661       0.000199     0.014877
# 3        0.037077 -37.214072          3.344187       0.000990     0.011546
# 4        0.037077 -37.214072          3.344187       0.000990     0.011546
# ..            ...        ...               ...            ...          ...
# 302      0.084522   2.304386         -3.546968       0.000489    -0.003990
# 303      0.024381   3.322802         -3.473863       0.000633    -0.004264
# 304      0.078238   2.620384         -3.375746       0.000889    -0.004038
# 305      0.083826  -8.396733         -3.858935       0.000155    -0.004245
# 306      0.001827 -21.926142         -3.449151       0.000690    -0.013777
#
# [307 rows x 29 columns]

# %%
np.unique(xQTLs_expr_metab_prot_methyl.geneSymbol)
# Out:
# array(['AADAT', 'AASS', 'ABCB8', 'ABCG1', 'ACAA1', 'ACAD8', 'ACADS',
#        'ADI1', 'ADK', 'AGPS', 'ALDH3A2', 'ALDH9A1', 'AMACR', 'AMD1',
#        'AQP1', 'ARG2', 'ASIC2', 'ASL', 'ASPA', 'CACNA1B', 'CAMK2D', 'CDA',
#        'CHDH', 'CHKA', 'CMPK2', 'COASY', 'DGKB', 'DGKE', 'DLD', 'EGFR',
#        'ENOPH1', 'ENPP2', 'FZD7', 'GART', 'GNAS', 'GPD1L', 'GRM5', 'HAAO',
#        'HNMT', 'HTR2A', 'IARS2', 'IDH1', 'ITPA', 'L2HGDH', 'MAP2K2',
#        'MGST3', 'MTHFD1L', 'NADSYN1', 'NEU3', 'NME3', 'OGDH', 'PAFAH1B3',
#        'PAICS', 'PDE10A', 'PDE4B', 'PDE4D', 'PDE8B', 'PDGFRB', 'PLCB2',
#        'PLCB4', 'PLD1', 'PPAT', 'PRKAA2', 'PRKCB', 'PRKG1', 'RPTOR',
#        'SAT2', 'SETMAR', 'TK2', 'TSC1', 'TUBA4A', 'TUBB6', 'UCKL1'],
#       dtype=object)

# %%
xQTLs_expr_metab_prot_methyl.to_csv("analysis_using_meta_eQTL/xQTLs_expr_metab_prot_methyl.csv", index=False)

# %% [raw]
# # END
